# %%
# !git clone https://github.com/stockmarkteam/ner-wikipedia-dataset.git
# Out:
# fatal: destination path 'ner-wikipedia-dataset' already exists and is not an empty directory.

# %%
# !pip install torch transformers fugashi ipadic sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (1.9.1)
# Requirement already satisfied: transformers in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (4.10.3)
# Requirement already satisfied: fugashi in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (1.1.1)
# Requirement already satisfied: ipadic in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (1.0.0)
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: typing-extensions in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: sacremoses in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: packaging in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (21.0)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (0.0.17)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: filelock in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (4.62.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from transformers) (2021.8.28)
# Requirement already satisfied: scikit-learn in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from sklearn) (1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from requests->transformers) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from sacremoses->transformers) (8.0.1)
# Requirement already satisfied: scipy>=1.1.0 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chibaren/Library/Python/3.8/lib/python/site-packages (from scikit-learn->sklearn) (2.2.0)
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# WARNING: You are using pip version 21.2.2; however, version 21.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from collections import defaultdict
import json
import pandas as pd
import openpyxl

from sklearn.model_selection import train_test_split
import torch
from transformers import BertConfig, BertJapaneseTokenizer
from transformers import BertModel
from transformers import BertForTokenClassification
from transformers import pipeline
from transformers import Trainer, TrainingArguments

# %%
MAX_LENGTH = 256  # 最大文長 
BERT_MODEL = "cl-tohoku/bert-base-japanese"  # 使用する学習済みモデル
DATASET_PATH = "ner-wikipedia-dataset/ner.json"

# %%
tokenizer = BertJapaneseTokenizer.from_pretrained('cl-tohoku/bert-base-japanese-whole-word-masking')

# %%
with open(DATASET_PATH) as json_file:  # データセット読み込み
    ner_data_dict_list = json.load(json_file)
text_list = [ner_data_dict["text"] for ner_data_dict in ner_data_dict_list]
encoded_text_list = []  # エンコードされた文のリスト
split_text_list = []  # 単語ごとに分割された文のリスト

for text in text_list:
    encoded_text = tokenizer(text, max_length=MAX_LENGTH, pad_to_max_length=True)
    encoded_text_list.append(encoded_text)
    split_text = tokenizer.decode(encoded_text["input_ids"]).split()
    split_text_list.append(split_text)

entities_list = [ner_data_dict["entities"] for ner_data_dict in ner_data_dict_list]
labels_list = [["O"] * MAX_LENGTH for _ in range(len(text_list))]
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /Users/chibaren/Library/Python/3.8/lib/python/site-packages/transformers/tokenization_utils_base.py:2184: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
unique_labels = set("O")  # 付与された固有表現抽出ラベルの集合
found_named_entity = False

for sample_idx, (encoded_text, split_text, entities) in enumerate(zip(encoded_text_list, split_text_list, entities_list)):
    if len(entities) == 0:
        continue
    target_entity = entities.pop(0)
    entity_name = target_entity["name"]
    entity_label = target_entity["type"]
    for word_idx, word in enumerate(split_text):
        if word == "[CLS]" or word == "[SEP]" or word == "[PAD]":  # 特殊トークンにIGNOREラベルの付与
            labels_list[sample_idx][word_idx] = "IGNORE"
            continue
        
        if len(entities) == 0:
            continue
            
        if entity_name.startswith(word):
            if entity_name.endswith(word):
                label = f"B-{entity_label}"
                labels_list[sample_idx][word_idx] = label
                unique_labels.add(label)
                
                if len(entities) >= 1:
                    target_entity = entities.pop(0)
                    entity_name = target_entity["name"]
                    entity_label = target_entity["type"]
                
            else:
                for word_idx_2 in range(word_idx + 1, len(split_text)):
                    if "".join(split_text[word_idx : word_idx_2 + 1]) not in entity_name.replace(" ", "").replace("　",""):
                        found_named_entity = False
                        break
                    if entity_name.endswith(split_text[word_idx_2]):
                        labels = [f"B-{entity_label}"] + [f"I-{entity_label}"] * (word_idx_2 - word_idx) 
                        unique_labels |= set(labels)
                        labels_list[sample_idx][word_idx : word_idx_2 + 1] = labels
                        found_named_entity = True
                        break
                if found_named_entity:
                    if len(entities) >= 1:
                        target_entity = entities.pop(0)
                        entity_name = target_entity["name"]
                        entity_label = target_entity["type"]

# %%
unique_labels = list(unique_labels)
label2id = {label : label_id for label_id, label in enumerate(unique_labels)}  # ラベルにIDを付与
label2id["IGNORE"] = -100  # IGNORE ラベル に ID -100 を付与
encoded_labels_list = [[label2id[label] for label in labels] for labels in labels_list]  # 各文に付与されたラベルをIDで置き換えたもののリストを作成
del label2id["IGNORE"]  # configに渡すときには消す必要あり
id2label= {id: label for label, id in label2id.items()}  # IDをkey、ラベル名をvalueとした逆の辞書を作成

# %%
class NERDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = defaultdict(list)
        for encoding_dict in encodings:
            for key, value in encoding_dict.items():
                self.encodings[key].append(value)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], device=torch.device('cuda'))
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_encoded_text_list, test_encoded_text_list, train_encoded_labels_list, test_encoded_labels_list = \
    train_test_split(encoded_text_list, encoded_labels_list, test_size=0.1, random_state=0)
train_encoded_text_list, val_encoded_text_list, train_encoded_labels_list, val_encoded_labels_list = \
    train_test_split(encoded_text_list, encoded_labels_list, test_size=0.2, random_state=0)

train_dataset = NERDataset(train_encoded_text_list, train_encoded_labels_list)
val_dataset = NERDataset(val_encoded_text_list, val_encoded_labels_list)
test_dataset = NERDataset(test_encoded_text_list, test_encoded_labels_list)

# %%
config = BertConfig.from_pretrained(BERT_MODEL, id2label=id2label, label2id=label2id)
model = BertForTokenClassification.from_pretrained('cl-tohoku/bert-base-japanese', config=config)
# Out:
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir='./results',          
    num_train_epochs=3,              
    per_device_train_batch_size=16,  
    per_device_eval_batch_size=64,   
    warmup_steps=500, 
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    save_steps=50,
    do_eval=True,
    eval_steps=50
)

# %%
trainer = Trainer(
    model=model,                         
    args=training_args, 
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

trainer.train()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='804' max='804' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [804/804 11:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.734000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.639700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.435100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.129500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.684200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.081500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.658600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.571300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.616800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.475300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.516300</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.477100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.416400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.392800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.472700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.411800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.397900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.326100</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.386900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.446900</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.349500</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.351500</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.297100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.280500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.298500</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.324400</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.353300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.214600</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.243800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.264700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.245400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.265300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.245800</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.243800</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.274900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.224200</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.237800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.265600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.241300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.191200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.285000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.205200</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.223500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.210700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.229300</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.220600</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.265900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.224500</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.200200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.209300</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.182200</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.179100</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.209000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.175800</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.146600</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.148500</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.134000</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.131400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.138500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.164500</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.156700</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.139900</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.147300</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.142400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.122700</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.140600</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.130500</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.105200</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.123600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.150900</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.131300</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.113400</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.113200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.126700</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.117700</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.150000</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.133000</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.119900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.146200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.137000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=804, training_loss=0.38880041608614707, metrics={'train_runtime': 719.8049, 'train_samples_per_second': 1.117, 'total_flos': 2167189457126400.0, 'epoch': 3.0, 'init_mem_cpu_alloc_delta': 1598495, 'init_mem_gpu_alloc_delta': 440950272, 'init_mem_cpu_peaked_delta': 58137, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 345076, 'train_mem_gpu_alloc_delta': 1391537152, 'train_mem_cpu_peaked_delta': 99520322, 'train_mem_gpu_peaked_delta': 4541236224})

# %%
model_path = 'model.pth'
torch.save(model.state_dict(), model_path)

# %%
print(encoded_labels_list)

# %%
df_test = pd.read_csv('textdata_from_twitter.csv', names=["text", "label1", "label2", "label3", "label4", "label5"])

# %%
df_test
# Out:
#                                                   text  label1   label2  \
# 0    ブログを更新しました 若林 愛 「木管五重奏カラフルアウトリーチ」 ⇒ https://am...    若林 愛    木管五重奏
# 1                      滝巡り④\n亀田不動の滝\n\n#ninja1000\n#滝沢  亀田不動の滝      NaN
# 2    『小岩井農場』日本最大の総合農場に行ってきましたの！【前編】 #小岩井農場 #上丸牛舎 #牛...   小岩井農場      NaN
# 3    フードアトリエです！\n本日12時～12時半頃まで滝沢市役所入口にて出張販売始めました！\n...   滝沢市役所  フードアトリエ
# 4    『ゆいてとて』 １０月２日(土)・３日(日) 10:00〜16:00 ゆい工房 結の蔵にて開...    ゆい工房    ゆいてとて
# ..                                                 ...     ...      ...
# 143            盛岡市中心部からちょっと走れば…\n#盛岡市\n#ダム\n#コンビニ弁当冷めた     NaN      NaN
# 144  近ツーの東北のホテル・旅館 https://tabitabilink.com/knt/eri...     NaN      NaN
# 145                                           @tabi317     NaN      NaN
# 146                                                 より     NaN      NaN
# 147  【#地域おこし協力隊募集】 #岩手県 #盛岡市 ①市総合交流ターミナルの利用促進と地域活性化...     NaN      NaN
#
#     label3 label4 label5
# 0      NaN    NaN    NaN
# 1      NaN    NaN    NaN
# 2      NaN    NaN    NaN
# 3      お惣菜   出張販売    NaN
# 4      NaN    NaN    NaN
# ..     ...    ...    ...
# 143    NaN    NaN    NaN
# 144    NaN    NaN    NaN
# 145    NaN    NaN    NaN
# 146    NaN    NaN    NaN
# 147    NaN    NaN    NaN
#
# [148 rows x 6 columns]

# %%
df_val = df_test['text']

# %%
model_path = 'model.pth'
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
raw_inputs = df_val.values.tolist()
print(raw_inputs[0:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/52/mldswh851q304f074xyvcvz00000gn/T/ipykernel_1341/178152467.py in <module>
# ----> 1 raw_inputs = df_val.values.tolist()
#       2 print(raw_inputs[0:5])
#
# NameError: name 'df_val' is not defined

# %%
raw_inputs = [str(t) for t in raw_inputs]

# %%
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, config=config)

# %%
import re

def clean_text(text):
    replaced_text = text.lower()
    replaced_text = re.sub(r'[【】]', ' ', replaced_text)       # 【】の除去
    replaced_text = re.sub(r'[（）()]', ' ', replaced_text)     # （）の除去
    replaced_text = re.sub(r'[［］\[\]]', ' ', replaced_text)   # ［］の除去
    replaced_text = re.sub(r'[@＠]\w+', '', replaced_text)  # メンションの除去
    replaced_text = re.sub(
        r'https?:\/\/.*?[\r\n ]', '', replaced_text)  # URLの除去
    replaced_text = re.sub(r'　', ' ', replaced_text)  # 全角空白の除去
    return replaced_text


def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    cleaned_text = soup.get_text()
    cleaned_text = ''.join(cleaned_text.splitlines())
    return cleaned_text


def clean_html_and_js_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    [x.extract() for x in soup.findAll(['script', 'style'])]
    cleaned_text = soup.get_text()
    cleaned_text = ''.join(cleaned_text.splitlines())
    return cleaned_text


def clean_url(html_text):
    cleaned_text = re.sub(r'http\S+', '', html_text)
    return cleaned_text

# %%
for i, text in enumerate(raw_inputs):
    raw_inputs[i] = clean_text(text)
    raw_inputs[i] = clean_url(text)

# %%
raw_inputs

# %%
predictions = []
for text in raw_inputs:
    predictions.append(ner_pipeline(text))

# %%
ner_pipeline("盛岡寿司懐石 重兵衛")
# Out:
# [{'entity': 'I-政治的組織名',
#   'score': 0.08448078,
#   'index': 2,
#   'word': '寿司',
#   'start': None,
#   'end': None},
#  {'entity': 'I-政治的組織名',
#   'score': 0.09784629,
#   'index': 3,
#   'word': '懐',
#   'start': None,
#   'end': None},
#  {'entity': 'I-政治的組織名',
#   'score': 0.11476692,
#   'index': 4,
#   'word': '##石',
#   'start': None,
#   'end': None},
#  {'entity': 'I-政治的組織名',
#   'score': 0.100545764,
#   'index': 5,
#   'word': '重',
#   'start': None,
#   'end': None},
#  {'entity': 'I-製品名',
#   'score': 0.09412962,
#   'index': 6,
#   'word': '兵衛',
#   'start': None,
#   'end': None}]

# %%
predictions
# Out:
# [[{'entity': 'I-人名',
#    'score': 0.0818402,
#    'index': 1,
#    'word': 'ブログ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10631643,
#    'index': 2,
#    'word': 'を',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0865674,
#    'index': 3,
#    'word': '更新',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08585945,
#    'index': 4,
#    'word': 'し',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.09210798,
#    'index': 5,
#    'word': 'まし',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.075507015,
#    'index': 7,
#    'word': '若林',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.105016336,
#    'index': 9,
#    'word': '「',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.13268644,
#    'index': 11,
#    'word': '##管',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1284447,
#    'index': 12,
#    'word': '五',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.10754939,
#    'index': 14,
#    'word': 'カラ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09309764,
#    'index': 15,
#    'word': '##フル',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1466623,
#    'index': 16,
#    'word': '##アウト',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.13521817,
#    'index': 17,
#    'word': '##リー',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09934098,
#    'index': 18,
#    'word': '##チ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.088394634,
#    'index': 20,
#    'word': '[UNK]',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.08425109,
#    'index': 21,
#    'word': 'http',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.07981312,
#    'index': 22,
#    'word': '##s',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09309472,
#    'index': 23,
#    'word': '://',
#    'start': None,
#    'end': None},
#   {'entity': 'I-地名',
#    'score': 0.07322405,
#    'index': 24,
#    'word': 'am',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.08745762,
#    'index': 25,
#    'word': '##eb',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08843462,
#    'index': 26,
#    'word': '##lo',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.091893636,
#    'index': 27,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09901316,
#    'index': 29,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09801296,
#    'index': 31,
#    'word': '##g',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09634113,
#    'index': 32,
#    'word': '##u',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09938709,
#    'index': 33,
#    'word': '-',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08852163,
#    'index': 35,
#    'word': '##a',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09581464,
#    'index': 36,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.14626077,
#    'index': 37,
#    'word': 'en',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09873134,
#    'index': 38,
#    'word': '##t',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09441254,
#    'index': 40,
#    'word': '-',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11882682,
#    'index': 41,
#    'word': '127',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10516495,
#    'index': 42,
#    'word': '##00',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08776955,
#    'index': 45,
#    'word': '##5',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09560146,
#    'index': 46,
#    'word': '##9',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.13348272,
#    'index': 49,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.10636497,
#    'index': 50,
#    'word': 'h',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.098704025,
#    'index': 51,
#    'word': '##t',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09985428,
#    'index': 54,
#    'word': '...',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08636733,
#    'index': 55,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.0959523,
#    'index': 56,
#    'word': 'アメ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09570977,
#    'index': 57,
#    'word': '##ブロ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.09900905,
#    'index': 58,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.094737716,
#    'index': 59,
#    'word': 'アウト',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09928381,
#    'index': 60,
#    'word': 'リーチ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09511193,
#    'index': 61,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.08478918,
#    'index': 63,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09405435,
#    'index': 64,
#    'word': '盛岡',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09083587,
#    'index': 65,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.090484135,
#    'index': 66,
#    'word': '宮古',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09781734,
#    'index': 67,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.084737726,
#    'index': 68,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10031592,
#    'index': 69,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09276976,
#    'index': 70,
#    'word': '二',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.087069534,
#    'index': 72,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12396931,
#    'index': 73,
#    'word': 'クラリネット',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09643943,
#    'index': 74,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.10785862,
#    'index': 75,
#    'word': '木',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.14688113,
#    'index': 76,
#    'word': '##管',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.13542838,
#    'index': 77,
#    'word': '五',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10279875,
#    'index': 78,
#    'word': '重奏',
#    'start': None,
#    'end': None}],
#  [{'entity': 'I-人名',
#    'score': 0.090249695,
#    'index': 1,
#    'word': '滝',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.097282164,
#    'index': 2,
#    'word': '巡り',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09976686,
#    'index': 3,
#    'word': '4',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09791482,
#    'index': 4,
#    'word': '亀田',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10096632,
#    'index': 5,
#    'word': '不動',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10855435,
#    'index': 7,
#    'word': '##滝',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.115916036,
#    'index': 8,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12765533,
#    'index': 9,
#    'word': 'n',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0903491,
#    'index': 11,
#    'word': '##ja',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10444803,
#    'index': 13,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08400152,
#    'index': 14,
#    'word': '滝沢',
#    'start': None,
#    'end': None}],
#  [{'entity': 'B-人名',
#    'score': 0.088733785,
#    'index': 1,
#    'word': '『',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.110091135,
#    'index': 2,
#    'word': '小',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.14470622,
#    'index': 3,
#    'word': '##岩',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1264108,
#    'index': 4,
#    'word': '##井',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10880494,
#    'index': 5,
#    'word': '農場',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09057567,
#    'index': 6,
#    'word': '』',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.10477591,
#    'index': 7,
#    'word': '日本',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.10598688,
#    'index': 8,
#    'word': '最大',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.092040576,
#    'index': 9,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.116765514,
#    'index': 10,
#    'word': '総合',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10256019,
#    'index': 11,
#    'word': '農場',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08692157,
#    'index': 13,
#    'word': '行っ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.099109426,
#    'index': 14,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.123864114,
#    'index': 15,
#    'word': 'き',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.08958685,
#    'index': 16,
#    'word': 'まし',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09060059,
#    'index': 17,
#    'word': 'た',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.109609164,
#    'index': 18,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.0973958,
#    'index': 19,
#    'word': '!',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1681295,
#    'index': 20,
#    'word': '##【',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11300919,
#    'index': 21,
#    'word': '前',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.112604395,
#    'index': 23,
#    'word': '】',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.091350295,
#    'index': 24,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11016281,
#    'index': 25,
#    'word': '小',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.13986374,
#    'index': 26,
#    'word': '##岩',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.13000338,
#    'index': 27,
#    'word': '##井',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10615975,
#    'index': 28,
#    'word': '農場',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.10268826,
#    'index': 29,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11244936,
#    'index': 30,
#    'word': '上',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.090359405,
#    'index': 31,
#    'word': '##丸',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09494944,
#    'index': 33,
#    'word': '##舎',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.088867664,
#    'index': 34,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09408046,
#    'index': 35,
#    'word': '牛',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09426477,
#    'index': 36,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09315883,
#    'index': 37,
#    'word': '羊',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09077457,
#    'index': 38,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09230087,
#    'index': 39,
#    'word': '馬',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08837221,
#    'index': 40,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.087220594,
#    'index': 41,
#    'word': '[UNK]',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10143716,
#    'index': 42,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.094417,
#    'index': 43,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10042939,
#    'index': 44,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08818046,
#    'index': 45,
#    'word': '岩手',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10974885,
#    'index': 46,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.08623987,
#    'index': 47,
#    'word': 'は',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.09978868,
#    'index': 48,
#    'word': '##て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.08750741,
#    'index': 49,
#    'word': '##な',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.088064924,
#    'index': 50,
#    'word': 'ブログ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09437192,
#    'index': 51,
#    'word': '『',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.106883325,
#    'index': 52,
#    'word': '小',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.15367532,
#    'index': 53,
#    'word': '##岩',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12605193,
#    'index': 54,
#    'word': '##井',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.104446955,
#    'index': 55,
#    'word': '農場',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.091136575,
#    'index': 56,
#    'word': '』',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.10572124,
#    'index': 57,
#    'word': '日本',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.107553095,
#    'index': 58,
#    'word': '最大',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.09315585,
#    'index': 59,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09555878,
#    'index': 60,
#    'word': '民間',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.117450975,
#    'index': 61,
#    'word': '総合',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.104072034,
#    'index': 62,
#    'word': '農場',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.083320946,
#    'index': 64,
#    'word': '行っ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10673525,
#    'index': 65,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.104627684,
#    'index': 66,
#    'word': 'き',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09536584,
#    'index': 67,
#    'word': 'まし',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.0948642,
#    'index': 68,
#    'word': 'た',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.10402197,
#    'index': 69,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-施設名',
#    'score': 0.093340576,
#    'index': 70,
#    'word': '!',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.17431769,
#    'index': 71,
#    'word': '##【',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10642338,
#    'index': 72,
#    'word': '前',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11194144,
#    'index': 74,
#    'word': '】',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09001539,
#    'index': 75,
#    'word': '-',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.085731074,
#    'index': 76,
#    'word': '元',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11616564,
#    'index': 77,
#    'word': 'IT',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09889306,
#    'index': 78,
#    'word': '土方',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11370574,
#    'index': 79,
#    'word': 'の',
#    'start': None,
#    'end': None}],
#  [{'entity': 'I-人名',
#    'score': 0.080564685,
#    'index': 1,
#    'word': 'フード',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.09838647,
#    'index': 3,
#    'word': 'です',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09103205,
#    'index': 4,
#    'word': '!',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09991396,
#    'index': 5,
#    'word': '本',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08899286,
#    'index': 6,
#    'word': '##日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.08796534,
#    'index': 8,
#    'word': '時',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.08524194,
#    'index': 9,
#    'word': '~',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10539423,
#    'index': 10,
#    'word': '12',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10004666,
#    'index': 11,
#    'word': '時半',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09089855,
#    'index': 12,
#    'word': '頃',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.088778585,
#    'index': 14,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09171273,
#    'index': 15,
#    'word': '市役所',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.1024917,
#    'index': 16,
#    'word': '入口',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09605721,
#    'index': 17,
#    'word': 'にて',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10010293,
#    'index': 18,
#    'word': '出張',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.08901041,
#    'index': 19,
#    'word': '販売',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.105126254,
#    'index': 20,
#    'word': '始め',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.10156936,
#    'index': 21,
#    'word': 'まし',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.09541393,
#    'index': 22,
#    'word': 'た',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08746726,
#    'index': 23,
#    'word': '!',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.08487921,
#    'index': 24,
#    'word': '日替わり',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.090630956,
#    'index': 25,
#    'word': 'で',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.0929311,
#    'index': 26,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.115833715,
#    'index': 27,
#    'word': '惣',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.093637474,
#    'index': 28,
#    'word': '##菜',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.084723696,
#    'index': 29,
#    'word': 'や',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.085290834,
#    'index': 30,
#    'word': 'お菓子',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.0810432,
#    'index': 31,
#    'word': 'など',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.08722463,
#    'index': 32,
#    'word': '販売',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10273902,
#    'index': 33,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08666025,
#    'index': 34,
#    'word': '予定',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.13084784,
#    'index': 35,
#    'word': 'です',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08892681,
#    'index': 36,
#    'word': '!',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.088313125,
#    'index': 37,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.084534876,
#    'index': 38,
#    'word': '近く',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10488266,
#    'index': 40,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09761959,
#    'index': 41,
#    'word': '##越し',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.12894563,
#    'index': 42,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08894548,
#    'index': 43,
#    'word': '際',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.088989176,
#    'index': 45,
#    'word': '覗',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.0890537,
#    'index': 46,
#    'word': '##い',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10517151,
#    'index': 47,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.079311065,
#    'index': 48,
#    'word': 'もらえる',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09307924,
#    'index': 49,
#    'word': 'と',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.08373081,
#    'index': 50,
#    'word': '嬉',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.09773429,
#    'index': 52,
#    'word': 'です',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09239437,
#    'index': 53,
#    'word': 'よろ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.10460788,
#    'index': 54,
#    'word': '##しく',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09016329,
#    'index': 55,
#    'word': 'お願い',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11250063,
#    'index': 56,
#    'word': 'いた',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.085042335,
#    'index': 58,
#    'word': 'ま',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.1456062,
#    'index': 59,
#    'word': '~',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.100043304,
#    'index': 60,
#    'word': 'す',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10803843,
#    'index': 61,
#    'word': 'Sm',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.0837665,
#    'index': 63,
#    'word': '##ing',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10289057,
#    'index': 64,
#    'word': 'f',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10753274,
#    'index': 65,
#    'word': '##ace',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10228429,
#    'index': 66,
#    'word': 'with',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10687659,
#    'index': 67,
#    'word': 'op',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09534035,
#    'index': 68,
#    'word': '##en',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11855656,
#    'index': 69,
#    'word': 'm',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.08642605,
#    'index': 70,
#    'word': '##out',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.108564354,
#    'index': 71,
#    'word': '##h',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10259589,
#    'index': 73,
#    'word': 't',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11618067,
#    'index': 75,
#    'word': '##ly',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.10432494,
#    'index': 76,
#    'word': '-',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.14378193,
#    'index': 77,
#    'word': 'cl',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.13390112,
#    'index': 78,
#    'word': '##ose',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.091412015,
#    'index': 79,
#    'word': '##d',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10783885,
#    'index': 80,
#    'word': 'e',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08396198,
#    'index': 82,
#    'word': '##s',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09408785,
#    'index': 83,
#    'word': '(',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.084252946,
#    'index': 84,
#    'word': '今',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.108969994,
#    'index': 85,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1159799,
#    'index': 86,
#    'word': 'ところ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08125995,
#    'index': 87,
#    'word': '販売',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.115450665,
#    'index': 88,
#    'word': '日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.096765414,
#    'index': 90,
#    'word': '不定期',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.11443932,
#    'index': 91,
#    'word': 'です',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08451972,
#    'index': 92,
#    'word': 'Per',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.08550021,
#    'index': 93,
#    'word': '##son',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11631286,
#    'index': 94,
#    'word': 'b',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.12694068,
#    'index': 95,
#    'word': '##ow',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10990173,
#    'index': 97,
#    'word': 'de',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11340458,
#    'index': 99,
#    'word': '##ly',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08132779,
#    'index': 100,
#    'word': ')',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09548934,
#    'index': 101,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08495621,
#    'index': 102,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.098106764,
#    'index': 103,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11119843,
#    'index': 105,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12117855,
#    'index': 106,
#    'word': '惣',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.10380481,
#    'index': 107,
#    'word': '##菜',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08591607,
#    'index': 108,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.09952857,
#    'index': 109,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09101839,
#    'index': 110,
#    'word': '弁当',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08634618,
#    'index': 111,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08330726,
#    'index': 112,
#    'word': 'フード',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.081481695,
#    'index': 113,
#    'word': 'アトリエ',
#    'start': None,
#    'end': None}],
#  [{'entity': 'I-人名',
#    'score': 0.086071916,
#    'index': 1,
#    'word': '『',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.100568816,
#    'index': 2,
#    'word': 'ゆい',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10222464,
#    'index': 3,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.14643493,
#    'index': 4,
#    'word': 'と',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.114190355,
#    'index': 5,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09109861,
#    'index': 6,
#    'word': '』',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.13219342,
#    'index': 7,
#    'word': '10',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10219238,
#    'index': 8,
#    'word': '月',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.09831822,
#    'index': 10,
#    'word': '日',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09953505,
#    'index': 11,
#    'word': '(',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.118202694,
#    'index': 13,
#    'word': ')',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11464101,
#    'index': 14,
#    'word': '・',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.109750554,
#    'index': 15,
#    'word': '3',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.10308585,
#    'index': 16,
#    'word': '日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.119238175,
#    'index': 17,
#    'word': '(',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.097859144,
#    'index': 18,
#    'word': '日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.089583606,
#    'index': 19,
#    'word': ')',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.102539904,
#    'index': 20,
#    'word': '10',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.098291524,
#    'index': 22,
#    'word': '00',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.096093975,
#    'index': 25,
#    'word': ':',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.110186525,
#    'index': 26,
#    'word': '00',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09042343,
#    'index': 27,
#    'word': 'ゆい',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08812896,
#    'index': 28,
#    'word': '工房',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.1021524,
#    'index': 29,
#    'word': '結',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10969928,
#    'index': 30,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09621543,
#    'index': 33,
#    'word': '開催',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.09043846,
#    'index': 34,
#    'word': '焼き',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.0836753,
#    'index': 35,
#    'word': 'たて',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10258365,
#    'index': 36,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09404237,
#    'index': 39,
#    'word': 'たち',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.10603762,
#    'index': 40,
#    'word': 'も',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08881909,
#    'index': 41,
#    'word': '参',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.09802493,
#    'index': 42,
#    'word': '##り',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.093631625,
#    'index': 43,
#    'word': 'ます',
#    'start': None,
#    'end': None},
#   {'entity': 'B-地名',
#    'score': 0.102062345,
#    'index': 44,
#    'word': '。',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.088037044,
#    'index': 45,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0870775,
#    'index': 46,
#    'word': 'クラフト',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10452918,
#    'index': 47,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08900808,
#    'index': 49,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09033471,
#    'index': 50,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.08555434,
#    'index': 51,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0866756,
#    'index': 52,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08918647,
#    'index': 53,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.103595264,
#    'index': 54,
#    'word': '秋',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12372663,
#    'index': 55,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09912372,
#    'index': 56,
#    'word': 'イベント',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.0939013,
#    'index': 57,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08858298,
#    'index': 58,
#    'word': '岩手',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09466219,
#    'index': 59,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.096000426,
#    'index': 60,
#    'word': 'りん',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.113956824,
#    'index': 61,
#    'word': '工房',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09747193,
#    'index': 62,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.089174666,
#    'index': 63,
#    'word': '磁器',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.116578005,
#    'index': 64,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.09176145,
#    'index': 65,
#    'word': 'class',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.09096294,
#    'index': 66,
#    'word': '##ical',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.0991989,
#    'index': 67,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08315294,
#    'index': 68,
#    'word': 'c',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.088000976,
#    'index': 69,
#    'word': '##era',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09323314,
#    'index': 70,
#    'word': '##m',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.094091,
#    'index': 71,
#    'word': '##ics',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09991375,
#    'index': 72,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08779719,
#    'index': 73,
#    'word': 'c',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.086940266,
#    'index': 74,
#    'word': '##era',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09071733,
#    'index': 75,
#    'word': '##m',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.11795506,
#    'index': 76,
#    'word': '##ics',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09965426,
#    'index': 77,
#    'word': '##t',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.10744585,
#    'index': 78,
#    'word': '##udio',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.0867347,
#    'index': 79,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.097255304,
#    'index': 80,
#    'word': 'ゆい',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09624998,
#    'index': 81,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11965068,
#    'index': 82,
#    'word': 'と',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08229226,
#    'index': 83,
#    'word': 'て',
#    'start': None,
#    'end': None}],
#  [{'entity': 'I-政治的組織名',
#    'score': 0.09692989,
#    'index': 1,
#    'word': 'おはよう',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11351116,
#    'index': 2,
#    'word': 'ござい',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.10080018,
#    'index': 3,
#    'word': 'ます',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.095031664,
#    'index': 4,
#    'word': '。',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.12087658,
#    'index': 5,
#    'word': '本',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.092578456,
#    'index': 6,
#    'word': '##日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08854217,
#    'index': 7,
#    'word': 'も',
#    'start': None,
#    'end': None},
#   {'entity': 'B-その他の組織名',
#    'score': 0.08485507,
#    'index': 8,
#    'word': '8',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09043246,
#    'index': 11,
#    'word': 'から',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09575694,
#    'index': 12,
#    'word': '営業',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09400602,
#    'index': 13,
#    'word': 'し',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09337595,
#    'index': 14,
#    'word': 'て',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10701687,
#    'index': 15,
#    'word': 'い',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.10644876,
#    'index': 16,
#    'word': 'ます',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.10831364,
#    'index': 17,
#    'word': '。',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09346432,
#    'index': 18,
#    'word': 'イス',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10082753,
#    'index': 19,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08913155,
#    'index': 20,
#    'word': '張り',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0933915,
#    'index': 21,
#    'word': '##替え',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08844242,
#    'index': 22,
#    'word': '・',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.095903836,
#    'index': 23,
#    'word': '修理',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08417094,
#    'index': 24,
#    'word': '・',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09179736,
#    'index': 25,
#    'word': '製作',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09294921,
#    'index': 26,
#    'word': 'いた',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.09247365,
#    'index': 27,
#    'word': '##し',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.098519646,
#    'index': 28,
#    'word': 'ます',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.108223885,
#    'index': 29,
#    'word': '。',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08528038,
#    'index': 30,
#    'word': 'http',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.087261215,
#    'index': 31,
#    'word': '://',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.090053774,
#    'index': 32,
#    'word': 'k',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12716952,
#    'index': 33,
#    'word': '##ob',
#    'start': None,
#    'end': None},
#   {'entity': 'I-地名',
#    'score': 0.10595746,
#    'index': 34,
#    'word': '##ay',
#    'start': None,
#    'end': None},
#   {'entity': 'I-地名',
#    'score': 0.103207015,
#    'index': 35,
#    'word': '##ash',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.093948364,
#    'index': 37,
#    'word': '-',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.100007884,
#    'index': 38,
#    'word': 'is',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08523193,
#    'index': 39,
#    'word': '##u',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.1342698,
#    'index': 40,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.09397256,
#    'index': 41,
#    'word': 'com',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.10877028,
#    'index': 42,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08935211,
#    'index': 43,
#    'word': 'イス',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.111879006,
#    'index': 45,
#    'word': '椅子',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.08719225,
#    'index': 46,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.09903896,
#    'index': 47,
#    'word': 'いす',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.088733084,
#    'index': 48,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12007404,
#    'index': 49,
#    'word': '椅子',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10561418,
#    'index': 50,
#    'word': '張',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09452805,
#    'index': 51,
#    'word': '##替え',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.08002306,
#    'index': 52,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08705325,
#    'index': 53,
#    'word': '小林',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12549718,
#    'index': 54,
#    'word': '椅子',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11283383,
#    'index': 55,
#    'word': '工業',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.08276431,
#    'index': 56,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09434273,
#    'index': 57,
#    'word': '小林',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10270609,
#    'index': 58,
#    'word': 'イス',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.0848696,
#    'index': 59,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.078914165,
#    'index': 60,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10409974,
#    'index': 61,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10250301,
#    'index': 62,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10348093,
#    'index': 63,
#    'word': '巣',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10178973,
#    'index': 64,
#    'word': '子',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09787805,
#    'index': 65,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.085686274,
#    'index': 66,
#    'word': 's',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.1070423,
#    'index': 67,
#    'word': '##inc',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11264216,
#    'index': 69,
#    'word': '1969',
#    'start': None,
#    'end': None}],
#  [{'entity': 'B-製品名',
#    'score': 0.116830446,
#    'index': 2,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09938681,
#    'index': 3,
#    'word': '##き',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09798078,
#    'index': 4,
#    'word': 'ぃ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.092865184,
#    'index': 5,
#    'word': '##ちゃん',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10312905,
#    'index': 6,
#    'word': 'どん',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0964393,
#    'index': 7,
#    'word': '##より',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0953747,
#    'index': 8,
#    'word': 'お',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11456242,
#    'index': 9,
#    'word': '天気',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.082551524,
#    'index': 10,
#    'word': 'でも',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09256136,
#    'index': 11,
#    'word': 'き',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.11347098,
#    'index': 12,
#    'word': 'ぃ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.10863431,
#    'index': 13,
#    'word': '##ちゃん',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.104597524,
#    'index': 14,
#    'word': '##は',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.081416324,
#    'index': 15,
#    'word': '元気',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.099483535,
#    'index': 16,
#    'word': 'いっぱい',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.083425514,
#    'index': 17,
#    'word': 'です',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09615802,
#    'index': 18,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08751426,
#    'index': 19,
#    'word': 'do',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09550617,
#    'index': 20,
#    'word': '##g',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09832481,
#    'index': 21,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09541809,
#    'index': 22,
#    'word': 'be',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09337918,
#    'index': 24,
#    'word': '##le',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10241537,
#    'index': 26,
#    'word': 'ビー',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10332397,
#    'index': 27,
#    'word': '##グル',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09352461,
#    'index': 29,
#    'word': 'レモン',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.12091656,
#    'index': 30,
#    'word': '##ビー',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.099364676,
#    'index': 31,
#    'word': '##グル',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.078433976,
#    'index': 33,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08917827,
#    'index': 34,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.08181759,
#    'index': 36,
#    'word': '犬',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.089062095,
#    'index': 37,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.07920359,
#    'index': 38,
#    'word': 'いる',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.078338504,
#    'index': 39,
#    'word': '暮らし',
#    'start': None,
#    'end': None}],
#  [{'entity': 'B-製品名',
#    'score': 0.106682196,
#    'index': 1,
#    'word': '【',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09019863,
#    'index': 2,
#    'word': '更新',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.14503852,
#    'index': 3,
#    'word': '】',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10662331,
#    'index': 4,
#    'word': '###',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08599002,
#    'index': 5,
#    'word': '滝沢',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09033673,
#    'index': 6,
#    'word': '市',
#    'start': None,
#    'end': None},
# ...
#    'score': 0.10790846,
#    'index': 66,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09818702,
#    'index': 67,
#    'word': '山形',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11708477,
#    'index': 68,
#    'word': '県',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.103518344,
#    'index': 69,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.09251684,
#    'index': 70,
#    'word': '福島',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10598043,
#    'index': 71,
#    'word': '県',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.11092222,
#    'index': 72,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.109393045,
#    'index': 73,
#    'word': '仙台',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11144855,
#    'index': 74,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.101837054,
#    'index': 75,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.094254814,
#    'index': 76,
#    'word': '盛岡',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.113348216,
#    'index': 77,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.10487125,
#    'index': 78,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10028349,
#    'index': 79,
#    'word': '郡山',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11101565,
#    'index': 80,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09003116,
#    'index': 81,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09686309,
#    'index': 83,
#    'word': '##ツー',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09342201,
#    'index': 84,
#    'word': '##リスト',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.08345333,
#    'index': 85,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.108159594,
#    'index': 86,
#    'word': '近',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11651695,
#    'index': 87,
#    'word': 'ツー',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.097486414,
#    'index': 88,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.09195381,
#    'index': 89,
#    'word': 'k',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.107662894,
#    'index': 90,
#    'word': '##n',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09756583,
#    'index': 91,
#    'word': '##t',
#    'start': None,
#    'end': None}],
#  [{'entity': 'B-製品名',
#    'score': 0.09144645,
#    'index': 2,
#    'word': 't',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08927579,
#    'index': 3,
#    'word': '##ab',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10848485,
#    'index': 5,
#    'word': '31',
#    'start': None,
#    'end': None}],
#  [{'entity': 'B-製品名',
#    'score': 0.11533945,
#    'index': 1,
#    'word': 'より',
#    'start': None,
#    'end': None}],
#  [{'entity': 'I-人名',
#    'score': 0.10001213,
#    'index': 1,
#    'word': '【',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09903133,
#    'index': 2,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.08993913,
#    'index': 3,
#    'word': '地域',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12529701,
#    'index': 4,
#    'word': '##お',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.089059725,
#    'index': 5,
#    'word': '##こし',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09531469,
#    'index': 6,
#    'word': '協力',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.08282113,
#    'index': 7,
#    'word': '隊',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.099386,
#    'index': 8,
#    'word': '募集',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12775785,
#    'index': 9,
#    'word': '】',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0977966,
#    'index': 10,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09349023,
#    'index': 11,
#    'word': '岩手',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11464045,
#    'index': 12,
#    'word': '県',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08976636,
#    'index': 13,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09661822,
#    'index': 14,
#    'word': '盛岡',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10212982,
#    'index': 15,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09639797,
#    'index': 17,
#    'word': '市',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11221527,
#    'index': 18,
#    'word': '総合',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10381715,
#    'index': 19,
#    'word': '交流',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.104559764,
#    'index': 20,
#    'word': 'ターミナル',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12619169,
#    'index': 21,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08496269,
#    'index': 22,
#    'word': '利用',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.085792184,
#    'index': 23,
#    'word': '促進',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08775475,
#    'index': 24,
#    'word': 'と',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.102299444,
#    'index': 25,
#    'word': '地域',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.13314085,
#    'index': 26,
#    'word': '活性',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.093295865,
#    'index': 27,
#    'word': '化',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.083307594,
#    'index': 29,
#    'word': '大学',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.093465336,
#    'index': 30,
#    'word': '連携',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09382267,
#    'index': 31,
#    'word': 'による',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09682399,
#    'index': 32,
#    'word': 'アグリ',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.095801786,
#    'index': 33,
#    'word': 'イノベーション',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09882264,
#    'index': 34,
#    'word': '事業',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.104111075,
#    'index': 35,
#    'word': '推進',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.0994322,
#    'index': 37,
#    'word': '芸術',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12436715,
#    'index': 38,
#    'word': '文化',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09607989,
#    'index': 39,
#    'word': 'まち',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.1050336,
#    'index': 40,
#    'word': 'づくり',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11193236,
#    'index': 41,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11747637,
#    'index': 42,
#    'word': '推進',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.11309373,
#    'index': 43,
#    'word': '4',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.101935394,
#    'index': 45,
#    'word': '##山',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11030133,
#    'index': 46,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10128545,
#    'index': 47,
#    'word': '産',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.095320396,
#    'index': 48,
#    'word': '##品',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10105055,
#    'index': 49,
#    'word': 'を',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09332193,
#    'index': 50,
#    'word': '道',
#    'start': None,
#    'end': None},
#   {'entity': 'B-政治的組織名',
#    'score': 0.11321833,
#    'index': 51,
#    'word': 'の',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.08969998,
#    'index': 52,
#    'word': '駅',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.092943,
#    'index': 53,
#    'word': 'から',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10001973,
#    'index': 54,
#    'word': '発信',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.09426945,
#    'index': 55,
#    'word': '人数',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.103377566,
#    'index': 56,
#    'word': ':',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.0872235,
#    'index': 57,
#    'word': '各',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10426404,
#    'index': 58,
#    'word': '1',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.10258806,
#    'index': 59,
#    'word': '名',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.09390787,
#    'index': 60,
#    'word': '期日',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.08848362,
#    'index': 61,
#    'word': ':',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09730422,
#    'index': 63,
#    'word': '3',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.09449225,
#    'index': 64,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.1027831,
#    'index': 65,
#    'word': '10',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09500155,
#    'index': 66,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.08189428,
#    'index': 67,
#    'word': '29',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.097716026,
#    'index': 68,
#    'word': '詳細',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.089821056,
#    'index': 69,
#    'word': 'は',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.1012299,
#    'index': 70,
#    'word': 'コ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.11087691,
#    'index': 71,
#    'word': '##チ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09814124,
#    'index': 72,
#    'word': '##ラ',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.082800746,
#    'index': 73,
#    'word': '[UNK]',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.09500488,
#    'index': 74,
#    'word': 'http',
#    'start': None,
#    'end': None},
#   {'entity': 'I-製品名',
#    'score': 0.111892745,
#    'index': 75,
#    'word': '://',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09766935,
#    'index': 76,
#    'word': 'c',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.08388708,
#    'index': 77,
#    'word': '##ity',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.1081271,
#    'index': 78,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.12727436,
#    'index': 79,
#    'word': 'm',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.103108354,
#    'index': 80,
#    'word': '##ori',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10486164,
#    'index': 81,
#    'word': '##ok',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09203537,
#    'index': 82,
#    'word': '##a',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11450459,
#    'index': 83,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09082873,
#    'index': 84,
#    'word': 'i',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.09829732,
#    'index': 85,
#    'word': '##w',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.085292794,
#    'index': 86,
#    'word': '##ate',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.10659836,
#    'index': 87,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.10565515,
#    'index': 89,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.086782336,
#    'index': 90,
#    'word': 'sh',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.11359534,
#    'index': 91,
#    'word': '##ise',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.10791925,
#    'index': 93,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09779031,
#    'index': 96,
#    'word': '##iz',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.112385005,
#    'index': 97,
#    'word': '##uk',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.116898224,
#    'index': 98,
#    'word': '##ur',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.09659624,
#    'index': 100,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09780492,
#    'index': 101,
#    'word': '102',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.11157785,
#    'index': 102,
#    'word': '##0',
#    'start': None,
#    'end': None},
#   {'entity': 'B-法人名',
#    'score': 0.11367093,
#    'index': 103,
#    'word': '##66',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.11031784,
#    'index': 105,
#    'word': '/',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.100326836,
#    'index': 106,
#    'word': 'ind',
#    'start': None,
#    'end': None},
#   {'entity': 'B-人名',
#    'score': 0.09303717,
#    'index': 107,
#    'word': '##e',
#    'start': None,
#    'end': None},
#   {'entity': 'I-政治的組織名',
#    'score': 0.104505904,
#    'index': 108,
#    'word': '##x',
#    'start': None,
#    'end': None},
#   {'entity': 'I-施設名',
#    'score': 0.12413207,
#    'index': 109,
#    'word': '.',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.1047281,
#    'index': 110,
#    'word': 'h',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.09591446,
#    'index': 111,
#    'word': '##t',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.09806299,
#    'index': 112,
#    'word': '##m',
#    'start': None,
#    'end': None},
#   {'entity': 'I-イベント名',
#    'score': 0.13505718,
#    'index': 113,
#    'word': '##l',
#    'start': None,
#    'end': None},
#   {'entity': 'I-その他の組織名',
#    'score': 0.09739313,
#    'index': 115,
#    'word': '#',
#    'start': None,
#    'end': None},
#   {'entity': 'B-製品名',
#    'score': 0.10021425,
#    'index': 116,
#    'word': 'イー',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.07890923,
#    'index': 117,
#    'word': '##ハト',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.09013157,
#    'index': 118,
#    'word': '##ー',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.08134497,
#    'index': 119,
#    'word': '部',
#    'start': None,
#    'end': None},
#   {'entity': 'I-法人名',
#    'score': 0.10751332,
#    'index': 120,
#    'word': 'に',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.10706088,
#    'index': 121,
#    'word': '入',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.095329985,
#    'index': 122,
#    'word': '##ろう',
#    'start': None,
#    'end': None},
#   {'entity': 'I-人名',
#    'score': 0.09147233,
#    'index': 123,
#    'word': '!',
#    'start': None,
#    'end': None}]]

# %%
import sys
from typing import List
from pprint import pprint
import spacy
import ginza

import pandas as pd

# %%
# 日本語自然言語処理のパイプラインを構築されたGiNZAをspaCyから読み込む
nlp = spacy.load('ja_ginza_electra')  

doc = nlp("『小岩井農場』日本最大の総合農場に行ってきましたの！【前編】 #小岩井農場 #上丸牛舎 #牛 #羊 #馬 #雫石 #滝沢 #岩手 #はてなブログ 『小岩井農場』日本最大の民間総合農場に行ってきましたの！【前編】 - 元IT土方の供述")

    
def tokenize(text: str) -> List[List[str]]:
    """
    日本語文を形態素解析する。
    Parameters
    ----------
    text : str
        解析対象の日本語テキスト。
    Returns
    -------
    List[List[str]]
        形態素解析結果。
    Notes
    -----
    * Token 属性の詳細については次のリンク先をご覧ください。
      https://spacy.io/api/token#attributes
    * Token.lemma_ の値は SudachiPy の Morpheme.dictionary_form() です。
    * Token.ent_type_ の詳細については次のリンク先をご覧ください。
      http://liat-aip.sakura.ne.jp/ene/ene8/definition_jp/html/enedetail.html
    """
    doc = nlp(text)

    attrs_list = []
    for token in doc:
        token_attrs = [
            token.i,  # トークン番号
            token.text,  # テキスト
            token.lemma_,  # 基本形
            ginza.reading_form(token),  # 読みカナ
            token.pos_,  # 品詞
            token.tag_,  # 品詞詳細
            ginza.inflection(token),  # 活用情報
            token.ent_type_  # 固有表現
        ]
        attrs_list.append([str(a) for a in token_attrs])

    return attrs_list

# pprint(tokenize("『小岩井農場』日本最大の総合農場に行ってきましたの！【前編】 #小岩井農場 #上丸牛舎 #牛 #羊 #馬 #雫石 #滝沢 #岩手 #はてなブログ 『小岩井農場』日本最大の民間総合農場に行ってきましたの！【前編】 - 元IT土方の供述"))

# %%
df_test = pd.read_csv('../textdata_from_twitter.csv', names=["text", "label1", "label2", "label3", "label4", "label5"])
df_val = df_test['text']

raw_inputs = df_val.values.tolist()
raw_inputs = [str(t) for t in raw_inputs]

# %%
for text in raw_inputs:
    pprint(tokenize(text))
# Out:
# [['0', 'ブログ', 'ブログ', 'ブログ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['1', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', '更新', '更新', 'コウシン', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['3', 'し', 'する', 'シ', 'AUX', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['4', 'まし', 'ます', 'マシ', 'AUX', '助動詞', '助動詞-マス,連用形-一般', ''],
#  ['5', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,終止形-一般', ''],
#  ['6', '若林', '若林', 'ワカバヤシ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'Person'],
#  ['7', '愛', '愛', 'アイ', 'PROPN', '名詞-普通名詞-一般', '', 'Person'],
#  ['8', '「', '「', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['9', '木管', '木管', 'モッカン', 'NOUN', '名詞-普通名詞-一般', '', 'Doctrine_Method_Other'],
#  ['10', '五', '五', 'ゴ', 'NUM', '名詞-数詞', '', 'Doctrine_Method_Other'],
#  ['11', '重', '重', 'ジュウ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Doctrine_Method_Other'],
#  ['12', '奏', '奏', 'ソウ', 'NOUN', '名詞-普通名詞-一般', '', 'Doctrine_Method_Other'],
#  ['13', 'カラフル', 'カラフル', 'カラフル', 'NOUN', '形状詞-一般', '', 'Doctrine_Method_Other'],
#  ['14',
#   'アウトリーチ',
#   'アウトリーチ',
#   'アウトリーチ',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Doctrine_Method_Other'],
#  ['15', '」', '」', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['16', '⇒', '⇒', 'キゴウ', 'NOUN', '補助記号-一般', '', ''],
#  ['17', 'https', 'https', 'https', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['18', ':', '：', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['19', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['20', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['21', 'ameblo', 'Ameblo', 'アメブロ', 'X', '名詞-固有名詞-一般', '', 'URL'],
#  ['22', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['23', 'jp', 'JP', 'ジェーピー', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['24', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['25', 'megu', 'megu', 'megu', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['26', '-', '－', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['27', 'cla', 'cla', 'cla', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['28', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['29', 'entry', 'entry', 'エントリー', 'X', '名詞-普通名詞-サ変可能', '', 'URL'],
#  ['30', '-', '－', 'カラ', 'X', '助詞-格助詞', '', 'URL'],
#  ['31',
#   '12700925918',
#   '12700925918',
#   'イチニナナレイレイキュウニゴキュウイチハチ',
#   'X',
#   '名詞-数詞',
#   '',
#   'URL'],
#  ['32', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['33', 'html', 'HTML', 'エイチティーエムエル', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['34', '…', '.', 'ドット', 'X', '補助記号-句点', '', ''],
#  ['35', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['36', 'アメブロ', 'アメブロ', 'アメブロ', 'NOUN', '名詞-固有名詞-一般', '', 'Product_Other'],
#  ['37', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['38', 'アウトリーチ', 'アウトリーチ', 'アウトリーチ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['39', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['40', '岩手', '岩手', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['41', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['42', '盛岡', '盛岡', 'モリオカ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['43', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['44', '宮古', '宮古', 'ミヤコ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'City'],
#  ['45', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['46', '滝沢', '滝沢', 'タキザワ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'City'],
#  ['47', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['48', '二', '二', 'ニ', 'NUM', '名詞-数詞', '', 'N_Location_Other'],
#  ['49', '戸', '戸', 'コ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'N_Location_Other'],
#  ['50', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['51', 'クラリネット', 'クラリネット', 'クラリネット', 'NOUN', '名詞-普通名詞-一般', '', 'Material'],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53', '木管', '木管', 'モッカン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['54', '五重奏', '五重奏', 'ゴジュウソウ', 'NOUN', '名詞-普通名詞-一般', '', '']]
# [['0', '滝巡り', '滝巡り', 'タキメグリ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['1', '④', '4', 'ヨン', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['2', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['3', '亀田', '亀田', 'カメダ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'Occasion_Other'],
#  ['4', '不動', '不動', 'フドウ', 'NOUN', '名詞-普通名詞-一般', '', 'Occasion_Other'],
#  ['5', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'Occasion_Other'],
#  ['6', '滝', '滝', 'タキ', 'NOUN', '名詞-普通名詞-一般', '', 'Occasion_Other'],
#  ['7', '\n\n', '\n\n', '\n\n', 'NOUN', '空白', '', ''],
#  ['8', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['9', 'ninja', 'NINJA', 'ニンジャ', 'NOUN', '名詞-普通名詞-一般', '', 'Sports_Facility'],
#  ['10', '1000', '1000', 'イチレイレイレイ', 'NUM', '名詞-数詞', '', 'Sports_Facility'],
#  ['11', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['12', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['13', '滝沢', '滝沢', 'タキザワ', 'NOUN', '名詞-固有名詞-人名-姓', '', 'Broadcast_Program']]
# [['0', '『', '『', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['1', '小岩井', '小岩井', 'コイワイ', 'PROPN', '名詞-固有名詞-一般', '', 'GOE_Other'],
#  ['2', '農場', '農場', 'ノウジョウ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['3', '』', '』', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['4', '日本', '日本', 'ニッポン', 'PROPN', '名詞-固有名詞-地名-国', '', 'Country'],
#  ['5', '最大', '最大', 'サイダイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['6', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['7', '総合', '総合', 'ソウゴウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['8', '農場', '農場', 'ノウジョウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['9', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['10', '行っ', '行く', 'イッ', 'VERB', '動詞-非自立可能', '五段-カ行,連用形-促音便', ''],
#  ['11', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['12', 'き', 'くる', 'キ', 'VERB', '動詞-非自立可能', 'カ行変格,連用形-一般', ''],
#  ['13', 'まし', 'ます', 'マシ', 'AUX', '助動詞', '助動詞-マス,連用形-一般', ''],
#  ['14', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['15', 'の', 'の', 'ノ', 'PART', '助詞-終助詞', '', ''],
#  ['16', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['17', '【', '【', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['18', '前編', '前編', 'ゼンペン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['19', '】', '】', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['20', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['21', '小岩井', '小岩井', 'コイワイ', 'PROPN', '名詞-固有名詞-一般', '', 'GOE_Other'],
#  ['22', '農場', '農場', 'ノウジョウ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['23', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['24', '上丸', '上丸', 'ウエマル', 'PROPN', '名詞-固有名詞-人名-姓', '', 'GOE_Other'],
#  ['25', '牛舎', '牛舎', 'ギュウシャ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['26', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['27', '牛', '牛', 'ウシ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['28', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['29', '羊', '羊', 'ヒツジ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['30', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['31', '馬', '馬', 'ウマ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['32', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['33', '雫石', '雫石', 'シズクイシ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'City'],
#  ['34', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['35', '滝沢', '滝沢', 'タキザワ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'City'],
#  ['36', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['37', '岩手', '岩手', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['38', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['39', 'はてな', 'はてな', 'ハテナ', 'PROPN', '名詞-普通名詞-一般', '', 'Product_Other'],
#  ['40', 'ブログ', 'ブログ', 'ブログ', 'NOUN', '名詞-普通名詞-一般', '', 'Product_Other'],
#  ['41', '『', '『', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['42', '小岩井', '小岩井', 'コイワイ', 'PROPN', '名詞-固有名詞-一般', '', 'GOE_Other'],
#  ['43', '農場', '農場', 'ノウジョウ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['44', '』', '』', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['45', '日本', '日本', 'ニッポン', 'PROPN', '名詞-固有名詞-地名-国', '', 'School'],
#  ['46', '最大', '最大', 'サイダイ', 'NOUN', '名詞-普通名詞-一般', '', 'School'],
#  ['47', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'School'],
#  ['48', '民間', '民間', 'ミンカン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['49', '総合', '総合', 'ソウゴウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['50', '農場', '農場', 'ノウジョウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['51', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['52', '行っ', '行く', 'イッ', 'VERB', '動詞-非自立可能', '五段-カ行,連用形-促音便', ''],
#  ['53', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['54', 'き', 'くる', 'キ', 'VERB', '動詞-非自立可能', 'カ行変格,連用形-一般', ''],
#  ['55', 'まし', 'ます', 'マシ', 'AUX', '助動詞', '助動詞-マス,連用形-一般', ''],
#  ['56', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['57', 'の', 'の', 'ノ', 'PART', '助詞-終助詞', '', ''],
#  ['58', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['59', '【', '【', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['60', '前編', '前編', 'ゼンペン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['61', '】', '】', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['62', '-', '－', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['63', '元', '元', 'モト', 'NOUN', '名詞-普通名詞-一般', '', 'Position_Vocation'],
#  ['64', 'IT', 'IT', 'アイティー', 'NOUN', '名詞-普通名詞-一般', '', 'Position_Vocation'],
#  ['65', '土方', '土方', 'ヒジカタ', 'NOUN', '名詞-固有名詞-人名-姓', '', 'Position_Vocation'],
#  ['66', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['67', '供述', '供述', 'キョウジュツ', 'NOUN', '名詞-普通名詞-サ変可能', '', '']]
# [['0', 'フード', 'フード', 'フード', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['1', 'アトリエ', 'アトリエ', 'アトリエ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['2', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['3', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['4', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['5', '本日', '本日', 'ホンジツ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['6', '12', '12', 'イチニ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['7', '時', '時', 'ジ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Time'],
#  ['8', '～', '～', 'カラ', 'SYM', '助詞-格助詞', '', 'Time'],
#  ['9', '12', '12', 'イチニ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['10', '時半', '時半', 'ジハン', 'NOUN', '接尾辞-名詞的-助数詞', '', 'Time'],
#  ['11', '頃', '頃', 'コロ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Time'],
#  ['12', 'まで', 'まで', 'マデ', 'ADP', '助詞-副助詞', '', ''],
#  ['13',
#   '滝沢市',
#   '滝沢市',
#   'タキザワシ',
#   'PROPN',
#   '名詞-固有名詞-地名-一般',
#   '',
#   'Public_Institution'],
#  ['14', '役所', '役所', 'ヤクショ', 'NOUN', '名詞-普通名詞-一般', '', 'Public_Institution'],
#  ['15', '入口', '入口', 'イリグチ', 'NOUN', '名詞-普通名詞-一般', '', 'Public_Institution'],
#  ['16', 'にて', 'にて', 'ニテ', 'ADP', '助詞-格助詞', '', ''],
#  ['17', '出張', '出張', 'シュッチョウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['18', '販売', '販売', 'ハンバイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['19', '始め', '始める', 'ハジメ', 'VERB', '動詞-非自立可能', '下一段-マ行,連用形-一般', ''],
#  ['20', 'まし', 'ます', 'マシ', 'AUX', '助動詞', '助動詞-マス,連用形-一般', ''],
#  ['21', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,終止形-一般', ''],
#  ['22', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['23', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['24', '日替わり', '日替わり', 'ヒガワリ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['25', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['26', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['27', '惣菜', '惣菜', 'ソウザイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['28', 'や', 'や', 'ヤ', 'ADP', '助詞-副助詞', '', ''],
#  ['29', 'お菓子', 'お菓子', 'オカシ', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['30', 'など', 'など', 'ナド', 'ADP', '助詞-副助詞', '', ''],
#  ['31', '販売', '販売', 'ハンバイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['32', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['33', '予定', '予定', 'ヨテイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['34', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['35', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['36', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['37', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['38', '近く', '近く', 'チカク', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['39', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['40', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['41', '越し', '越す', 'コシ', 'VERB', '動詞-一般', '五段-サ行,連用形-一般', ''],
#  ['42', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['43', '際', '際', 'サイ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['44', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['45', '覗い', '覗く', 'ノゾイ', 'VERB', '動詞-一般', '五段-カ行,連用形-イ音便', ''],
#  ['46', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['47', 'もらえる', 'もらえる', 'モラエル', 'VERB', '動詞-非自立可能', '下一段-ア行,終止形-一般', ''],
#  ['48', 'と', 'と', 'ト', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['49', '嬉しい', '嬉しい', 'ウレシイ', 'ADJ', '形容詞-一般', '形容詞,終止形-一般', ''],
#  ['50', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['51', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['52', 'よろしく', 'よろしく', 'ヨロシク', 'ADV', '副詞', '', ''],
#  ['53', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['54', '願い', '願う', 'ネガイ', 'VERB', '動詞-非自立可能', '五段-ワア行,連用形-一般', ''],
#  ['55', 'い', 'いる', 'イ', 'VERB', '動詞-非自立可能', '上一段-ア行,連用形-一般', ''],
#  ['56', 'た', 'た', 'タ', 'ADP', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['57', 'しま', 'しま', 'シマ', 'AUX', '名詞-普通名詞-一般', '', ''],
#  ['58', '～', '～', 'カラ', 'AUX', '助詞-格助詞', '', ''],
#  ['59', 'す', 'す', 'ス', 'AUX', '接頭辞', '', ''],
#  ['60', 'Smiling', 'smiling', 'Smiling', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['61', 'face', 'FACE', 'フェース', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['62', 'with', 'with', 'ウィズ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['63', 'open', 'Open', 'オープン', 'NOUN', '名詞-普通名詞-サ変形状詞可能', '', ''],
#  ['64', 'mouth', 'mouth', 'マウス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['65', 'and', 'AND', 'アンド', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['66', 'tightly', 'tightly', 'tightly', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['67', '-', '－', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['68', 'closed', 'closed', 'クローズド', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['69', 'eyes', 'Eyes', 'アイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['70', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['71', '(', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['72', '今', '今', 'イマ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['73', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['74', 'ところ', 'ところ', 'トコロ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['75', '販売', '販売', 'ハンバイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['76', '日', '日', 'ヒ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['77', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['78', '不定期', '不定期', 'フテイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['79', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['80', 'Person', 'person', 'パーソン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['81', 'bowing', 'bowing', 'bowing', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['82', 'deeply', 'deeply', 'deeply', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['83', ')', ')', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['84', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['85', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['86', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['87', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['88', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['89', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', 'Dish'],
#  ['90', '惣菜', '惣菜', 'ソウザイ', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['91', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['92', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['93', 'お弁当', 'お弁当', 'オベントウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['94', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['95', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['96', 'フード', 'フード', 'フード', 'NOUN', '名詞-普通名詞-一般', '', 'Corporation_Other'],
#  ['97', 'アトリエ', 'アトリエ', 'アトリエ', 'NOUN', '名詞-普通名詞-一般', '', 'Corporation_Other']]
# [['0', '『', '『', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['1', 'ゆい', 'ゆう', 'ユイ', 'PROPN', '動詞-一般', '五段-ワア行,連用形-一般', 'Movie'],
#  ['2', 'て', 'て', 'テ', 'NOUN', '助詞-接続助詞', '', 'Movie'],
#  ['3', 'とて', 'とて', 'トテ', 'NOUN', '助詞-格助詞', '', 'Movie'],
#  ['4', '』', '』', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', 'Movie'],
#  ['5', '１０', '10', 'イチレイ', 'NUM', '名詞-数詞', '', 'Date'],
#  ['6', '月', '月', 'ガツ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Date'],
#  ['7', '２', '2', 'ニ', 'NUM', '名詞-数詞', '', 'Date'],
#  ['8', '日', '日', 'ニチ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Date'],
#  ['9', '(', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['10', '土', '土', 'ド', 'NOUN', '名詞-普通名詞-一般', '', 'Day_Of_Week'],
#  ['11', ')', ')', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['12', '・', '・', '・', 'SYM', '補助記号-一般', '', ''],
#  ['13', '３', '3', 'ミッ', 'NUM', '名詞-数詞', '', ''],
#  ['14', '日', '日', 'カ', 'NOUN', '接尾辞-名詞的-助数詞', '', 'Day_Of_Week'],
#  ['15', '(', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['16', '日', '日', 'ニチ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Day_Of_Week'],
#  ['17', ')', ')', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['18', '10', '10', 'イチレイ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['19', ':', '：', 'キゴウ', 'SYM', '補助記号-一般', '', 'Time'],
#  ['20', '00', '00', 'レイレイ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['21', '〜', '〜', 'キゴウ', 'SYM', '補助記号-一般', '', 'Time'],
#  ['22', '16', '16', 'イチロク', 'NUM', '名詞-数詞', '', 'Time'],
#  ['23', ':', '：', 'キゴウ', 'SYM', '補助記号-一般', '', 'Time'],
#  ['24', '00', '00', 'レイレイ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['25', 'ゆい', 'ゆい', 'ユイ', 'NOUN', '名詞-固有名詞-人名-名', '', 'GOE_Other'],
#  ['26', '工房', '工房', 'コウボウ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['27', '結', '結', 'ケツ', 'PROPN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['28', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'GOE_Other'],
#  ['29', '蔵', '蔵', 'クラ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['30', 'にて', 'にて', 'ニテ', 'ADP', '助詞-格助詞', '', ''],
#  ['31', '開催', '開催', 'カイサイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['32', '焼きたて', '焼きたて', 'ヤキタテ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['33', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['34', '新しい', '新しい', 'アタラシイ', 'ADJ', '形容詞-一般', '形容詞,連体形-一般', ''],
#  ['35', '器', '器', 'ウツワ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['36', 'たち', 'たち', 'タチ', 'NOUN', '接尾辞-名詞的-一般', '', ''],
#  ['37', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['38', '参り', '参る', 'マイリ', 'VERB', '動詞-非自立可能', '五段-ラ行,連用形-一般', ''],
#  ['39', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['40', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['41', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['42', 'クラフト', 'クラフト', 'クラフト', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['43', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['44', 'クラフト', 'クラフト', 'クラフト', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['45', '市', '市', 'シ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['46', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['47', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['48', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['49', '秋', '秋', 'アキ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Date'],
#  ['50', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['51', 'イベント', 'イベント', 'イベント', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53', '岩手', '岩手', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['54', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['55', 'りん', 'りん', 'リン', 'NOUN', '副詞', '', 'GOE_Other'],
#  ['56', '工房', '工房', 'コウボウ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['57', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['58', '磁器', '磁器', 'ジキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['59', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['60', 'classical', 'classical', 'classical', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['61', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['62',
#   'ceramics',
#   'ceramics',
#   'ceramics',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Academic'],
#  ['63', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['64',
#   'ceramicstudio',
#   'ceramicstudio',
#   'ceramicstudio',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'GOE_Other'],
#  ['65', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['66', 'ゆい', 'ゆう', 'ユイ', 'PROPN', '動詞-一般', '五段-ワア行,連用形-一般', 'Movie'],
#  ['67', 'て', 'て', 'テ', 'NOUN', '助詞-接続助詞', '', 'Movie'],
#  ['68', 'とて', 'とて', 'トテ', 'NOUN', '助詞-格助詞', '', 'Movie']]
# [['0', 'おはようございます', 'おはようございます', 'オハヨウゴザイマス', 'INTJ', '感動詞-一般', '', ''],
#  ['1', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['2', '本日', '本日', 'ホンジツ', 'ADV', '名詞-普通名詞-副詞可能', '', ''],
#  ['3', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['4', '8', '8', 'ハチ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['5', '：', '：', 'キゴウ', 'SYM', '補助記号-一般', '', 'Time'],
#  ['6', '30', '30', 'サンレイ', 'NUM', '名詞-数詞', '', 'Time'],
#  ['7', 'から', 'から', 'カラ', 'ADP', '助詞-格助詞', '', ''],
#  ['8', '営業', '営業', 'エイギョウ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['9', 'し', 'する', 'シ', 'AUX', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['10', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['11', 'い', 'いる', 'イ', 'VERB', '動詞-非自立可能', '上一段-ア行,連用形-一般', ''],
#  ['12', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['13', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['14', 'イス', 'イス', 'イス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['15', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['16', '張り替え', '張り替え', 'ハリカエ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['17', '・', '・', '・', 'SYM', '補助記号-一般', '', ''],
#  ['18', '修理', '修理', 'シュウリ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['19', '・', '・', '・', 'SYM', '補助記号-一般', '', ''],
#  ['20', '製作', '製作', 'セイサク', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['21', 'いたし', 'いたす', 'イタシ', 'AUX', '動詞-非自立可能', '五段-サ行,連用形-一般', ''],
#  ['22', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['23', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['24', 'http://', 'http:／／', 'エイチティーティーピー', 'X', '記号-一般', '', 'URL'],
#  ['25', 'kobayashi', 'kobayashi', 'kobayashi', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['26', '-', '－', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['27', 'isu', 'isu', 'isu', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['28', '.com', '.com', 'コム', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['29', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['30', 'イス', 'イス', 'イス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['31', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['32', '椅子', '椅子', 'イス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['33', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['34', 'いす', 'いす', 'イス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['35', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['36', '椅子', '椅子', 'イス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['37', '張替え', '張替え', 'ハリカエ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['38', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['39', '小林', '小林', 'コバヤシ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'Company'],
#  ['40', '椅子', '椅子', 'イス', 'NOUN', '名詞-普通名詞-一般', '', 'Company'],
#  ['41', '工業', '工業', 'コウギョウ', 'NOUN', '名詞-普通名詞-一般', '', 'Company'],
#  ['42', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['43', '小林', '小林', 'コバヤシ', 'PROPN', '名詞-固有名詞-人名-姓', '', 'Company'],
#  ['44', 'イス', 'イス', 'イス', 'NOUN', '名詞-普通名詞-一般', '', 'Company'],
#  ['45', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['46', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['47', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['48', '巣子', '巣子', 'スゴ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Person'],
#  ['49', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['50', 'since', 'since', 'since', 'NOUN', '名詞-普通名詞-一般', '', 'Date'],
#  ['51', '1969', '1969', 'イチキュウロクキュウ', 'NUM', '名詞-数詞', '', 'Date']]
# [['0', '今日', '今日', 'キョウ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['1', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', 'き', 'くる', 'キ', 'PROPN', '動詞-非自立可能', 'カ行変格,連用形-一般', 'Person'],
#  ['3', 'ぃ', 'ぃ', 'ィ', 'PROPN', '補助記号-一般', '', 'Person'],
#  ['4', 'ちゃん', 'ちゃん', 'チャン', 'NOUN', '接尾辞-名詞的-一般', '', 'Title_Other'],
#  ['5', 'どんより', 'どんより', 'ドンヨリ', 'ADV', '副詞', '', ''],
#  ['6', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['7', '天気', '天気', 'テンキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['8', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['9', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['10', 'き', 'くる', 'キ', 'PROPN', '動詞-非自立可能', 'カ行変格,連用形-一般', 'Person'],
#  ['11', 'ぃ', 'ぃ', 'ィ', 'PROPN', '補助記号-一般', '', 'Person'],
#  ['12', 'ちゃん', 'ちゃん', 'チャン', 'NOUN', '接尾辞-名詞的-一般', '', 'Title_Other'],
#  ['13', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['14', '元気', '元気', 'ゲンキ', 'ADJ', '名詞-普通名詞-形状詞可能', '', ''],
#  ['15', 'いっぱい', 'いっぱい', 'イッパイ', 'ADJ', '名詞-普通名詞-形状詞可能', '', ''],
#  ['16', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['17', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['18', 'dog', 'dog', 'ドッグ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['19', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['20',
#   'beagle',
#   'beagle',
#   'beagle',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Corporation_Other'],
#  ['21', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['22', 'ビーグル', 'ビーグル', 'ビーグル', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['23', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['24', 'レモン', 'レモン', 'レモン', 'NOUN', '名詞-普通名詞-一般', '', 'Flora'],
#  ['25', 'ビーグル', 'ビーグル', 'ビーグル', 'NOUN', '名詞-普通名詞-一般', '', 'Flora'],
#  ['26', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['27', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['28', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['29', '犬', '犬', 'イヌ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['30', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['31', 'いる', 'いる', 'イル', 'VERB', '動詞-非自立可能', '上一段-ア行,連体形-一般', ''],
#  ['32', '暮らし', '暮らし', 'クラシ', 'NOUN', '名詞-普通名詞-一般', '', '']]
# [['0', '【', '【', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['1', '更新', '更新', 'コウシン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['2', '】', '】', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['3', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['4', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['5', '×', '×', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['6', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['7', 'ＩＧＲ', 'igr', 'ＩＧＲ', 'NOUN', '名詞-普通名詞-一般', '', 'Culture'],
#  ['8', 'ラッピング', 'ラッピング', 'ラッピング', 'NOUN', '名詞-普通名詞-サ変可能', '', 'Culture'],
#  ['9', '車両', '車両', 'シャリョウ', 'NOUN', '名詞-普通名詞-一般', '', 'Culture'],
#  ['10', '運行', '運行', 'ウンコウ', 'NOUN', '名詞-普通名詞-サ変可能', '', 'Culture'],
#  ['11', '情報', '情報', 'ジョウホウ', 'NOUN', '名詞-普通名詞-一般', '', 'Culture'],
#  ['12', '｜', '｜', 'キゴウ', 'X', '補助記号-一般', '', 'Culture'],
#  ['13', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', 'Email'],
#  ['14', 'ＩＧＲ', 'igr', 'ＩＧＲ', 'PROPN', '名詞-普通名詞-一般', '', 'Email'],
#  ['15', 'いわて', 'いわて', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Email'],
#  ['16', '銀河鉄道', '銀河鉄道', 'ギンガテツドウ', 'PROPN', '名詞-固有名詞-一般', '', 'Email'],
#  ['17', 'https', 'https', 'https', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['18', ':', '：', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['19', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['20', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['21', 'igr', 'igr', 'igr', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['22', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['23', 'jp', 'JP', 'ジェーピー', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['24', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['25', '2021', '2021', 'ニレイニイチ', 'X', '名詞-数詞', '', 'URL'],
#  ['26', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['27', '09', '09', 'レイキュウ', 'NUM', '名詞-数詞', '', 'URL'],
#  ['28', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['29', '29', '29', 'ニキュウ', 'X', '名詞-数詞', '', 'URL'],
#  ['30', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['31',
#   'takizawaigrdebut',
#   'takizawaigrdebut',
#   'takizawaigrdebut',
#   'X',
#   '名詞-普通名詞-一般',
#   '',
#   'URL'],
#  ['32', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL']]
# [['0', 'あなた', 'あなた', 'アナタ', 'PRON', '代名詞', '', ''],
#  ['1', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', '電話', '電話', 'デンワ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['3', 'する', 'する', 'スル', 'AUX', '動詞-非自立可能', 'サ行変格,連体形-一般', ''],
#  ['4', 'だけ', 'だけ', 'ダケ', 'PART', '助詞-副助詞', '', ''],
#  ['5', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['6', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['7', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['8', '施設', '施設', 'シセツ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['9', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['10', '雰囲気', '雰囲気', 'フンイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['11', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['12', '施設長', '施設長', 'シセツチョウ', 'NOUN', '名詞-普通名詞-一般', '', 'Position_Vocation'],
#  ['13', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['14', '雰囲気', '雰囲気', 'フンイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['15', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['16', '伝わり', '伝わる', 'ツタワリ', 'VERB', '動詞-一般', '五段-ラ行,連用形-一般', ''],
#  ['17', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['18', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['19', '見学', '見学', 'ケンガク', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['20', 'なし', 'なし', 'ナシ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['21', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['22', '利用', '利用', 'リヨウ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['23', 'し', 'する', 'シ', 'AUX', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['24', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['25', '方', '方', 'カタ', 'NOUN', '名詞-普通名詞-助数詞可能', '', ''],
#  ['26', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['27', 'い', 'いる', 'イ', 'VERB', '動詞-非自立可能', '上一段-ア行,連用形-一般', ''],
#  ['28', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['29', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['30', 'まず', 'まず', 'マズ', 'ADV', '副詞', '', ''],
#  ['31', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['32', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['33', '電話', '電話', 'デンワ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['34', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['35', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['36', '気持ち', '気持ち', 'キモチ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['37', '伺わ', '伺う', 'ウカガワ', 'VERB', '動詞-一般', '五段-ワア行,未然形-一般', ''],
#  ['38', 'せ', 'せる', 'セ', 'AUX', '助動詞', '下一段-サ行,連用形-一般', ''],
#  ['39', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['40', 'ください', 'くださる', 'クダサイ', 'AUX', '動詞-非自立可能', '五段-ラ行,命令形', ''],
#  ['41', '♩', '♩', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['42', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['43', '岩手県', '岩手県', 'イワテケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['44', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['45', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['46', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['47', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['48', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['49', 'デイサービス', 'デイサービス', 'デイサービス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['50', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['51', '介護', '介護', 'カイゴ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53', '介護施設', '介護施設', 'カイゴシセツ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['54', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['55', '通所', '通所', 'ツウショ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['56', '介護', '介護', 'カイゴ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['57', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['58', '楽', '楽', 'ラク', 'NOUN', '名詞-普通名詞-形状詞可能', '', '']]
# [['0', '小', '小', 'ショウ', 'NOUN', '接頭辞', '', ''],
#  ['1', '撮影', '撮影', 'サツエイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['2', '会', '会', 'カイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['3', '(', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['4', '自分', '自分', 'ジブン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['5', 'だけ', 'だけ', 'ダケ', 'ADP', '助詞-副助詞', '', ''],
#  ['6', ')', ')', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['7', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['8', 'IGR', 'igr', 'IGR', 'NOUN', '名詞-普通名詞-一般', '', 'Vehicle_Other'],
#  ['9', 'いわて', 'いわて', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Vehicle_Other'],
#  ['10', '銀河鉄道', '銀河鉄道', 'ギンガテツドウ', 'NOUN', '名詞-固有名詞-一般', '', ''],
#  ['11', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['12', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['13', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['14', '盛岡', '盛岡', 'モリオカ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City']]
# [['0', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['1', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', '知人', '知人', 'チジン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['3', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['4', '児童', '児童', 'ジドウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['5', '発達', '発達', 'ハッタツ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['6', '支援', '支援', 'シエン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['7', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['8', '放課後', '放課後', 'ホウカゴ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['9', '等', '等', 'トウ', 'NOUN', '接尾辞-名詞的-一般', '', ''],
#  ['10', 'デイサービス', 'デイサービス', 'デイサービス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['11', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['12', '設立', '設立', 'セツリツ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['13', 'する', 'する', 'スル', 'AUX', '動詞-非自立可能', 'サ行変格,連体形-一般', ''],
#  ['14', '予定', '予定', 'ヨテイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['15', 'な', 'だ', 'ナ', 'AUX', '助動詞', '助動詞-ダ,連体形-一般', ''],
#  ['16', 'の', 'の', 'ノ', 'SCONJ', '助詞-準体助詞', '', ''],
#  ['17', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['18', 'が', 'が', 'ガ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['19', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['20', '銀行', '銀行', 'ギンコウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['21', '融資', '融資', 'ユウシ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['22', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['23', '際', '際', 'サイ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['24', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['25', '事前', '事前', 'ジゼン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['26', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['27', '利用者', '利用者', 'リヨウシャ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['28', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['29', '確保', '確保', 'カクホ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['30', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['31', 'できる', 'できる', 'デキル', 'VERB', '動詞-非自立可能', '上一段-カ行,終止形-一般', ''],
#  ['32', 'か', 'か', 'カ', 'PART', '助詞-副助詞', '', ''],
#  ['33', '問わ', '問う', 'トワ', 'VERB', '動詞-一般', '五段-ワア行,未然形-一般', ''],
#  ['34', 'れ', 'れる', 'レ', 'AUX', '助動詞', '助動詞-レル,連用形-一般', ''],
#  ['35', 'て', 'てる', 'テ', 'AUX', '助動詞', '下一段-タ行,連用形-一般', ''],
#  ['36', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['37', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['38', 'どなた', 'どなた', 'ドナタ', 'PRON', '代名詞', '', ''],
#  ['39', 'か', 'か', 'カ', 'ADP', '助詞-副助詞', '', ''],
#  ['40', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['41', '設立', '設立', 'セツリツ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['42', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['43', '際', '際', 'サイ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['44', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['45', '利用', '利用', 'リヨウ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['46', 'し', 'する', 'シ', 'AUX', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['47', 'たい', 'たい', 'タイ', 'AUX', '助動詞', '助動詞-タイ,終止形-一般', ''],
#  ['48', 'と', 'と', 'ト', 'ADP', '助詞-格助詞', '', ''],
#  ['49', 'いう', 'いう', 'イウ', 'VERB', '動詞-一般', '五段-ワア行,連体形-一般', ''],
#  ['50', '方', '方', 'カタ', 'NOUN', '名詞-普通名詞-助数詞可能', '', ''],
#  ['51', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['52', 'いれ', 'いる', 'イレ', 'VERB', '動詞-非自立可能', '上一段-ア行,仮定形-一般', ''],
#  ['53', 'ば', 'ば', 'バ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['54', 'DM', 'DM', 'ディーエム', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['55', '願い', '願う', 'ネガイ', 'VERB', '動詞-非自立可能', '五段-ワア行,連用形-一般', ''],
#  ['56', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['57', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['58', 'ICT', 'ICT', 'アイシーティー', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['59', '療育', '療育', 'リョウイク', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['60', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['61', 'メーン', 'メーン', 'メーン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['62', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['63', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['64', '最新', '最新', 'サイシン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['65', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['66', '療育', '療育', 'リョウイク', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['67', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['68', '提供', '提供', 'テイキョウ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['69', 'し', 'する', 'シ', 'AUX', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['70', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['71', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['72', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['73', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['74', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City']]
# [['0', '今日', '今日', 'キョウ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['1', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', 'き', 'くる', 'キ', 'PROPN', '動詞-非自立可能', 'カ行変格,連用形-一般', 'Person'],
#  ['3', 'ぃ', 'ぃ', 'ィ', 'PROPN', '補助記号-一般', '', 'Person'],
#  ['4', 'ちゃん', 'ちゃん', 'チャン', 'NOUN', '接尾辞-名詞的-一般', '', 'Title_Other'],
#  ['5', '今日', '今日', 'キョウ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['6', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['7', '招き猫', '招き猫', 'マネキネコ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['8', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['9', '日', '日', 'ヒ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['10', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['11', 'dog', 'dog', 'ドッグ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['12', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['13', 'beagle', 'beagle', 'beagle', 'NOUN', '名詞-普通名詞-一般', '', 'Color_Other'],
#  ['14', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['15', 'ビーグル', 'ビーグル', 'ビーグル', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['16', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['17', 'レモン', 'レモン', 'レモン', 'NOUN', '名詞-普通名詞-一般', '', 'Flora'],
#  ['18', 'ビーグル', 'ビーグル', 'ビーグル', 'NOUN', '名詞-普通名詞-一般', '', 'Flora'],
#  ['19', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['20', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['21', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['22', '犬', '犬', 'イヌ', 'NOUN', '名詞-普通名詞-一般', '', 'Mammal'],
#  ['23', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['24', 'いる', 'いる', 'イル', 'VERB', '動詞-非自立可能', '上一段-ア行,連体形-一般', ''],
#  ['25', '暮らし', '暮らし', 'クラシ', 'NOUN', '名詞-普通名詞-一般', '', '']]
# [['0', 'ふんわり', 'ふんわり', 'フンワリ', 'ADV', '副詞', '', ''],
#  ['1', 'と', 'と', 'ト', 'ADP', '助詞-格助詞', '', ''],
#  ['2', 'し', 'する', 'シ', 'VERB', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['3', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['4', '言い方', '言い方', 'イイカタ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['5', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['6', 'けど', 'けど', 'ケド', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['7', '一番', '一番', 'イチバン', 'ADV', '副詞', '', 'Rank'],
#  ['8', '多い', '多い', 'オオイ', 'ADJ', '形容詞-一般', '形容詞,連体形-一般', ''],
#  ['9', '利用', '利用', 'リヨウ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['10', 'さ', 'する', 'サ', 'AUX', '動詞-非自立可能', 'サ行変格,未然形-サ', ''],
#  ['11', 'れ', 'れる', 'レ', 'AUX', '助動詞', '助動詞-レル,連用形-一般', ''],
#  ['12', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,連体形-一般', ''],
#  ['13', 'かた', 'かた', 'カタ', 'NOUN', '名詞-普通名詞-助数詞可能', '', ''],
#  ['14', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['15', '声', '声', 'コエ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['16', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['17', '…', '.', 'ドット', 'SYM', '補助記号-句点', '', ''],
#  ['18', '楽', '楽', 'ラク', 'NOUN', '名詞-普通名詞-形状詞可能', '', ''],
#  ['19', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['20', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['21', '他', '他', 'タ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['22', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['23', 'デイサービス', 'デイサービス', 'デイサービス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['24', 'と', 'と', 'ト', 'ADP', '助詞-格助詞', '', ''],
#  ['25', '雰囲気', '雰囲気', 'フンイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['26', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['27', '違う', '違う', 'チガウ', 'VERB', '動詞-一般', '五段-ワア行,終止形-一般', ''],
#  ['28', 'と', 'と', 'ト', 'ADP', '助詞-接続助詞', '', ''],
#  ['29', 'よく', 'よく', 'ヨク', 'ADV', '副詞', '', ''],
#  ['30', 'いわ', 'いう', 'イワ', 'VERB', '動詞-一般', '五段-ワア行,未然形-一般', ''],
#  ['31', 'れ', 'れる', 'レ', 'AUX', '助動詞', '助動詞-レル,連用形-一般', ''],
#  ['32', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['33', 'それ', 'それ', 'ソレ', 'PRON', '代名詞', '', ''],
#  ['34', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['35', '職員', '職員', 'ショクイン', 'NOUN', '名詞-普通名詞-一般', '', 'Position_Vocation'],
#  ['36', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['37', 'ゆったり', 'ゆったり', 'ユッタリ', 'ADV', '副詞', '', ''],
#  ['38', 'と', 'と', 'ト', 'ADP', '助詞-格助詞', '', ''],
#  ['39', 'し', 'する', 'シ', 'VERB', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['40', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['41', 'いる', 'いる', 'イル', 'VERB', '動詞-非自立可能', '上一段-ア行,終止形-一般', ''],
#  ['42', 'から', 'から', 'カラ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['43', 'だ', 'だ', 'ダ', 'AUX', '助動詞', '助動詞-ダ,終止形-一般', ''],
#  ['44', 'って', 'って', 'ッテ', 'ADP', '助詞-副助詞', '', ''],
#  ['45', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['46', '私達', '私達', 'ワタシタチ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['47', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['48', '忙しく', '忙しい', 'イソガシク', 'ADJ', '形容詞-一般', '形容詞,連用形-一般', ''],
#  ['49', 'し', 'する', 'シ', 'VERB', '動詞-非自立可能', 'サ行変格,連用形-一般', ''],
#  ['50', 'て', 'てる', 'テ', 'AUX', '助動詞', '下一段-タ行,連用形-一般', ''],
#  ['51', 'たら', 'た', 'タラ', 'AUX', '助動詞', '助動詞-タ,仮定形-一般', ''],
#  ['52', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['53', 'みな', 'みな', 'ミナ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['54', 'さん', 'さん', 'サン', 'NOUN', '接尾辞-名詞的-一般', '', ''],
#  ['55', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['56', '落ち着か', '落ち着く', 'オチツカ', 'VERB', '動詞-一般', '五段-カ行,未然形-一般', ''],
#  ['57', 'ない', 'ない', 'ナイ', 'AUX', '助動詞', '助動詞-ナイ,終止形-一般', ''],
#  ['58', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['59', 'よ', 'よ', 'ヨ', 'PART', '助詞-終助詞', '', ''],
#  ['60', 'ね', 'ね', 'ネ', 'PART', '助詞-終助詞', '', ''],
#  ['61', '施設長', '施設長', 'シセツチョウ', 'NOUN', '名詞-普通名詞-一般', '', 'Position_Vocation'],
#  ['62', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['63', '…', '.', 'ドット', 'SYM', '補助記号-句点', '', ''],
#  ['64', '抜け', '抜ける', 'ヌケ', 'VERB', '動詞-非自立可能', '下一段-カ行,連用形-一般', ''],
#  ['65', 'て', 'てる', 'テ', 'AUX', '助動詞', '下一段-タ行,連用形-一般', ''],
#  ['66', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['67', 'が', 'が', 'ガ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['68', '（', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['69', '笑', '笑', 'ワライ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['70', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['71', 'デイサービス', 'デイサービス', 'デイサービス', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['72', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['73', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['74', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['75', '岩手県', '岩手県', 'イワテケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['76', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['77', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['78', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['79', '楽', '楽', 'ラク', 'NOUN', '名詞-普通名詞-形状詞可能', '', '']]
# [['0', '岩手大学', '岩手大学', 'イワテダイガク', 'PROPN', '名詞-固有名詞-一般', '', 'School'],
#  ['1', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['2', '後期', '後期', 'コウキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['3', '集中', '集中', 'シュウチュウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['4', '講義', '講義', 'コウギ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['5', '（', '（', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['6', 'オンライン', 'オンライン', 'オンライン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['7', '）', ')', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['8', '、', '、', '、', 'PUNCT', '補助記号-読点', '', ''],
#  ['9', '1', '1', 'イチ', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['10', '日', '日', 'ニチ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Ordinal_Number'],
#  ['11', '目', '目', 'メ', 'NOUN', '接尾辞-名詞的-一般', '', 'Ordinal_Number'],
#  ['12', '午後', '午後', 'ゴゴ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Time'],
#  ['13', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['14', '部', '部', 'ブ', 'NOUN', '名詞-普通名詞-助数詞可能', '', ''],
#  ['15', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['16', '始まっ', '始まる', 'ハジマッ', 'VERB', '動詞-一般', '五段-ラ行,連用形-促音便', ''],
#  ['17', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['18', 'い', 'いる', 'イ', 'VERB', '動詞-非自立可能', '上一段-ア行,連用形-一般', ''],
#  ['19', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['20', 'Zoom', 'Zoom', 'ズーム', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['21', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['22', 'できる', 'できる', 'デキル', 'VERB', '動詞-非自立可能', '上一段-カ行,連体形-一般', ''],
#  ['23', '班', '班', 'ハン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['24', 'ワーク', 'ワーク', 'ワーク', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['25', '「', '「', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['26', 'ブレイク', 'ブレイク', 'ブレイク', 'NOUN', '名詞-普通名詞-一般', '', 'Game'],
#  ['27', 'アウト', 'アウト', 'アウト', 'NOUN', '名詞-普通名詞-一般', '', 'Game'],
#  ['28', 'ルーム', 'ルーム', 'ルーム', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['29', '」', '」', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['30', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['31', '活用', '活用', 'カツヨウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['32', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['33', 'モニター', 'モニター', 'モニター', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['34', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['35', '数', '数', 'カズ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['36', 'が', 'が', 'ガ', 'ADP', '助詞-格助詞', '', ''],
#  ['37', 'すごい', 'すごい', 'スゴイ', 'ADJ', '形容詞-一般', '形容詞,終止形-一般', ''],
#  ['38', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['39', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['40', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['41', 'オンライン', 'オンライン', 'オンライン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['42', '会議', '会議', 'カイギ', 'NOUN', '名詞-普通名詞-サ変可能', '', '']]
# [['0', 'GunjiTV', 'gunjitv', 'GunjiTV', 'NOUN', '名詞-普通名詞-一般', '', 'Theater'],
#  ['1', 'LIVE', 'LIVE', 'ライブ', 'NOUN', '名詞-普通名詞-一般', '', 'Theater'],
#  ['2', '＃', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['3', '１０', '10', 'イチレイ', 'NUM', '名詞-数詞', '', ''],
#  ['4',
#   'Michinoku',
#   'michinoku',
#   'Michinoku',
#   'PROPN',
#   '名詞-普通名詞-一般',
#   '',
#   'Company'],
#  ['5', 'pro', 'PRO', 'プロ', 'NOUN', '名詞-普通名詞-一般', '', 'Company'],
#  ['6',
#   'wrestling',
#   'wrestling',
#   'wrestling',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Company'],
#  ['7', 'https', 'https', 'https', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['8', ':', '：', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['9', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['10', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['11', 'youtu', 'youtu', 'youtu', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['12', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['13', 'be', 'Be', 'ビー', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['14', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['15', 'dvVZv', 'dvvzv', 'dvVZv', 'X', '名詞-固有名詞-一般', '', 'URL'],
#  ['16', '89', '89', 'ハチキュウ', 'X', '名詞-数詞', '', 'URL'],
#  ['17', 'DcMg', 'dcmg', 'DcMg', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['18', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['19', 'みちのく', 'みちのく', 'ミチノク', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Show'],
#  ['20', 'プロレス', 'プロレス', 'プロレス', 'NOUN', '名詞-普通名詞-一般', '', 'Show'],
#  ['21', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', 'Show'],
#  ['22', 'michipro', 'michipro', 'michipro', 'NOUN', '名詞-普通名詞-一般', '', 'Show'],
#  ['23', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['24', 'みち', 'みち', 'ミチ', 'NOUN', '名詞-普通名詞-一般', '', 'Product_Other'],
#  ['25', 'プロ', 'プロ', 'プロ', 'NOUN', '名詞-普通名詞-一般', '', 'Product_Other'],
#  ['26', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['27', '岩手', '岩手', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['28', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['29', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City']]
# [['0', '￥', '￥', 'キゴウ', 'SYM', '補助記号-一般', '', 'Money'],
#  ['1', '2000', '2000', 'ニレイレイレイ', 'NUM', '名詞-数詞', '', 'Money'],
#  ['2', '円', '円', 'エン', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Money'],
#  ['3', 'PayPay', 'PayPay', 'ペイペイ', 'NOUN', '名詞-固有名詞-一般', '', 'Product_Other'],
#  ['4', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['5', '¥', '￥', 'キゴウ', 'SYM', '補助記号-一般', '', 'Money'],
#  ['6', '400', '400', 'ヨンレイレイ', 'NUM', '名詞-数詞', '', 'Money'],
#  ['7', '円', '円', 'エン', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Money'],
#  ['8', '戻っ', '戻る', 'モドッ', 'VERB', '動詞-一般', '五段-ラ行,連用形-促音便', ''],
#  ['9', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,終止形-一般', ''],
#  ['10', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['11', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['12', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['13', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['14', '夏', '夏', 'ナツ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Religious_Festival'],
#  ['15', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'Religious_Festival'],
#  ['16',
#   'PayPay',
#   'PayPay',
#   'ペイペイ',
#   'PROPN',
#   '名詞-固有名詞-一般',
#   '',
#   'Occasion_Other'],
#  ['17',
#   'フェスティバル',
#   'フェスティバル',
#   'フェスティバル',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Occasion_Other'],
#  ['18', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['19', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['20', '今月末', '今月末', 'コンゲツマツ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['21', '迄', '迄', 'マデ', 'NOUN', '助詞-副助詞', '', ''],
#  ['22', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['23', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['24', 'ジャンボ', 'ジャンボ', 'ジャンボ', 'NOUN', '名詞-普通名詞-一般', '', 'Game'],
#  ['25', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['26', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['27', '今週', '今週', 'コンシュウ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['28', 'のみ', 'のみ', 'ノミ', 'ADP', '助詞-副助詞', '', ''],
#  ['29', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['30', '詳しく', '詳しい', 'クワシク', 'ADJ', '形容詞-一般', '形容詞,連用形-一般', ''],
#  ['31', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['32', 'ペイペイ', 'ペイペイ', 'ペイペイ', 'NOUN', '名詞-固有名詞-人名-一般', '', 'Product_Other'],
#  ['33', 'で', 'で', 'デ', 'ADP', '接続詞', '', ''],
#  ['34', '確認', '確認', 'カクニン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['35', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['36', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['37', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['38', '雫石町', '雫石町', 'シズクイシチョウ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['39', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['40', 'よしゃ', 'よす', 'ヨシャ', 'NOUN', '動詞-一般', '五段-サ行,仮定形-融合', 'Facility_Other'],
#  ['41', 'れ', 'れる', 'レ', 'NOUN', '助動詞', '助動詞-レル,連用形-一般', 'Facility_Other'],
#  ['42', '通り', '通り', 'トオリ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Facility_Other'],
#  ['43', '商店街', '商店街', 'ショウテンガイ', 'NOUN', '名詞-普通名詞-一般', '', 'Facility_Other'],
#  ['44', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['45', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['46', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['47', '土日', '土日', 'ドニチ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Day_Of_Week'],
#  ['48', 'ジャンボ', 'ジャンボ', 'ジャンボ', 'NOUN', '名詞-固有名詞-人名-一般', '', 'Occasion_Other'],
#  ['49', '市', '市', 'シ', 'NOUN', '名詞-普通名詞-一般', '', 'Occasion_Other'],
#  ['50', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['51', 'ペイペイ', 'ペイペイ', 'ペイペイ', 'NOUN', '名詞-固有名詞-人名-一般', '', 'Product_Other'],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53', '滝沢市', '滝沢市', 'タキザワシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['54', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['55', '夏', '夏', 'ナツ', 'NOUN', '名詞-普通名詞-副詞可能', '', 'Date'],
#  ['56', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['57',
#   'PayPay',
#   'PayPay',
#   'ペイペイ',
#   'PROPN',
# ...
#  ['43', '城跡', '城跡', 'ジョウセキ', 'NOUN', '名詞-普通名詞-一般', '', 'Facility_Other'],
#  ['44', '公園', '公園', 'コウエン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['45', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['46', '岩手', '岩手', 'イワテ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Worship_Place'],
#  ['47', '公園', '公園', 'コウエン', 'NOUN', '名詞-普通名詞-一般', '', 'Worship_Place'],
#  ['48', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['49',
#   'ハロウィン',
#   'ハロウィン',
#   'ハロウィン',
#   'NOUN',
#   '名詞-普通名詞-一般',
#   '',
#   'Religious_Festival'],
#  ['50', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['51', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53', 'モリ', 'モリ', 'モリ', 'PROPN', '名詞-固有名詞-人名-一般', '', 'Person'],
#  ['54', '子', '子', 'シ', 'X', '接尾辞-名詞的-一般', '', 'Person'],
#  ['55', 'https', 'https', 'https', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['56', ':', '：', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['57', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['58', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['59', 'instagr', 'instagr', 'instagr', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['60', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['61', 'am', 'AM', 'エーエム', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['62', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['63', 'p', 'p', 'p', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['64', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['65',
#   'CUUbgkYhUju',
#   'cuubgkyhuju',
#   'CUUbgkYhUju',
#   'X',
#   '名詞-普通名詞-一般',
#   '',
#   'URL'],
#  ['66', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL']]
# [['0', '明日', '明日', 'アス', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['1', 'も', 'も', 'モ', 'ADP', '助詞-係助詞', '', ''],
#  ['2', '晴れる', '晴れる', 'ハレル', 'VERB', '動詞-一般', '下一段-ラ行,終止形-一般', ''],
#  ['3', 'でしょう', 'です', 'デショウ', 'AUX', '助動詞', '助動詞-デス,意志推量形', ''],
#  ['4', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['5', '？', '？', 'キゴウ', 'PUNCT', '補助記号-句点', '', ''],
#  ['6', 'イイ', 'イイ', 'イイ', 'ADJ', '形容詞-非自立可能', '形容詞,連体形-一般', ''],
#  ['7', '夕焼け', '夕焼け', 'ユウヤケ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['8', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['9', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['10', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['11', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['12', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['13', '夕焼け', '夕焼け', 'ユウヤケ', 'NOUN', '名詞-普通名詞-一般', '', '']]
# [['0', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['1', 'ラーメン', 'ラーメン', 'ラーメン', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['2', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['3', 'ランチ', 'ランチ', 'ランチ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['4', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['5', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['6',
#   '盛岡市東見前',
#   '盛岡市東見前',
#   'モリオカシヒガシミルマエ',
#   'PROPN',
#   '名詞-固有名詞-地名-一般',
#   '',
#   'Postal_Address'],
#  ['7', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'Postal_Address'],
#  ['8', 'たまる', 'たまる', 'タマル', 'VERB', '動詞-一般', '五段-ラ行,連体形-一般', ''],
#  ['9', '盛岡', '盛岡', 'モリオカ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'GOE_Other'],
#  ['10', '南', '南', 'ミナミ', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['11', '店', '店', 'テン', 'NOUN', '接尾辞-名詞的-一般', '', 'GOE_Other'],
#  ['12', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['13', '特選', '特選', 'トクセン', 'NOUN', '名詞-普通名詞-サ変可能', '', 'Dish'],
#  ['14', '鶏', '鶏', 'ニワトリ', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['15', '中華', '中華', 'チュウカ', 'PROPN', '名詞-固有名詞-地名-国', '', 'Dish'],
#  ['16', '大', '大', 'ダイ', 'NOUN', '接尾辞-名詞的-一般', '', 'Dish'],
#  ['17', '820', '820', 'ハチニレイ', 'NUM', '名詞-数詞', '', 'Money'],
#  ['18', '円', '円', 'エン', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Money'],
#  ['19', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['20', '頂き', '頂く', 'イタダキ', 'VERB', '動詞-非自立可能', '五段-カ行,連用形-一般', ''],
#  ['21', 'まし', 'ます', 'マシ', 'AUX', '助動詞', '助動詞-マス,連用形-一般', ''],
#  ['22', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,終止形-一般', ''],
#  ['23', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['24', '麺', '麺', 'メン', 'NOUN', '名詞-普通名詞-一般', '', 'Food_Other'],
#  ['25', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['26', '細', '細', 'サイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['27', '・', '・', '・', 'SYM', '補助記号-一般', '', ''],
#  ['28', '太', '太', 'フトシ', 'NOUN', '名詞-固有名詞-人名-名', '', ''],
#  ['29', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['30', '選べ', '選べる', 'エラベ', 'VERB', '動詞-一般', '下一段-バ行,連用形-一般', ''],
#  ['31', 'て', 'て', 'テ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['32', '今日', '今日', 'キョウ', 'NOUN', '名詞-普通名詞-副詞可能', '', ''],
#  ['33', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['34', '太', '太い', 'フト', 'NOUN', '形容詞-一般', '形容詞,語幹-一般', 'Clothing'],
#  ['35', '麺', '麺', 'メン', 'NOUN', '名詞-普通名詞-一般', '', 'Clothing'],
#  ['36', '。', '。', '。', 'PUNCT', '補助記号-句点', '', ''],
#  ['37', 'とても', 'とても', 'トテモ', 'ADV', '副詞', '', ''],
#  ['38', '優しい', '優しい', 'ヤサシイ', 'ADJ', '形容詞-一般', '形容詞,連体形-一般', ''],
#  ['39', 'お', 'お', 'オ', 'NOUN', '接頭辞', '', ''],
#  ['40', '味', '味', 'アジ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['41', 'です', 'です', 'デス', 'AUX', '助動詞', '助動詞-デス,終止形-一般', ''],
#  ['42', 'が', 'が', 'ガ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['43', 'テーブル', 'テーブル', 'テーブル', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['44', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['45', 'ある', 'ある', 'アル', 'VERB', '動詞-非自立可能', '五段-ラ行,連体形-一般', ''],
#  ['46', '柚子', '柚子', 'ユズ', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['47', '酢', '酢', 'ス', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['48', 'や', 'や', 'ヤ', 'ADP', '助詞-副助詞', '', ''],
#  ['49', 'ラーメン', 'ラーメン', 'ラーメン', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['50', '醤油', '醤油', 'ショウユ', 'NOUN', '名詞-普通名詞-一般', '', 'Dish'],
#  ['51', 'で', 'で', 'デ', 'ADP', '助詞-格助詞', '', ''],
#  ['52', '調整', '調整', 'チョウセイ', 'VERB', '名詞-普通名詞-サ変可能', '', ''],
#  ['53', 'でき', 'できる', 'デキ', 'AUX', '動詞-非自立可能', '上一段-カ行,連用形-一般', ''],
#  ['54', 'ます', 'ます', 'マス', 'AUX', '助動詞', '助動詞-マス,終止形-一般', ''],
#  ['55', 'よ', 'よ', 'ヨ', 'PART', '助詞-終助詞', '', ''],
#  ['56', '。', '。', '。', 'PUNCT', '補助記号-句点', '', '']]
# [['0', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['1', '中心', '中心', 'チュウシン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['2', '部', '部', 'ブ', 'NOUN', '名詞-普通名詞-助数詞可能', '', ''],
#  ['3', 'から', 'から', 'カラ', 'ADP', '助詞-格助詞', '', ''],
#  ['4', 'ちょっと', 'ちょっと', 'チョット', 'ADV', '副詞', '', ''],
#  ['5', '走れ', '走る', 'ハシレ', 'VERB', '動詞-一般', '五段-ラ行,仮定形-一般', ''],
#  ['6', 'ば', 'ば', 'バ', 'SCONJ', '助詞-接続助詞', '', ''],
#  ['7', '…', '.', 'ドット', 'SYM', '補助記号-句点', '', ''],
#  ['8', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['9', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['10', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['11', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['12', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['13', 'ダム', 'ダム', 'ダム', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['14', '\n', '\n', '\n', 'NOUN', '空白', '', ''],
#  ['15', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['16', 'コンビニ', 'コンビニ', 'コンビニ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['17', '弁当', '弁当', 'ベントウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['18', '冷め', '冷める', 'サメ', 'VERB', '動詞-一般', '下一段-マ行,連用形-一般', ''],
#  ['19', 'た', 'た', 'タ', 'AUX', '助動詞', '助動詞-タ,終止形-一般', '']]
# [['0', '近ツー', '近ツー', 'キンツー', 'NOUN', '名詞-固有名詞-一般', '', 'Theory'],
#  ['1', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'Theory'],
#  ['2', '東北', '東北', 'トウホク', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Theory'],
#  ['3', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', 'Theory'],
#  ['4', 'ホテル', 'ホテル', 'ホテル', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['5', '・', '・', '・', 'SYM', '補助記号-一般', '', ''],
#  ['6', '旅館', '旅館', 'リョカン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['7', 'https', 'https', 'https', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['8', ':', '：', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['9', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['10', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['11',
#   'tabitabilink',
#   'tabitabilink',
#   'tabitabilink',
#   'X',
#   '名詞-普通名詞-一般',
#   '',
#   'URL'],
#  ['12', '.com', '.com', 'コム', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['13', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['14', 'knt', 'KNT', 'KNT', 'X', '名詞-固有名詞-一般', '', 'URL'],
#  ['15', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['16', 'eria', 'eria', 'eria', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['17', '-', '－', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['18', 'touhoku', 'touhoku', 'touhoku', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['19', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['20', 'index', 'INDEX', 'インデックス', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['21', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['22', 'html', 'HTML', 'エイチティーエムエル', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['23', '…', '.', 'ドット', 'X', '補助記号-句点', '', 'URL'],
#  ['24', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['25', '旅', '旅', 'タビ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['26', '旅', '旅', 'タビ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['27', 'リンク', 'リンク', 'リンク', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['28', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['29', '東北', '東北', 'トウホク', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Domestic_Region'],
#  ['30', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['31', 'ホテル', 'ホテル', 'ホテル', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['32', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['33', '旅館', '旅館', 'リョカン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['34', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['35', '青森県', '青森県', 'アオモリケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['36', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['37', '岩手県', '岩手県', 'イワテケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['38', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['39', '宮城県', '宮城県', 'ミヤギケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['40', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['41', '秋田県', '秋田県', 'アキタケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['42', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['43', '山形県', '山形県', 'ヤマガタケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['44', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['45', '福島県', '福島県', 'フクシマケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['46', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['47', '仙台市', '仙台市', 'センダイシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['48', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['49', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['50', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['51', '郡山市', '郡山市', 'コオリヤマシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'City'],
#  ['52', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['53',
#   '近畿日本ツーリスト',
#   '近畿日本ツーリスト',
#   'キンキニッポンツーリスト',
#   'PROPN',
#   '名詞-固有名詞-一般',
#   '',
#   'Show'],
#  ['54', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', 'Show'],
#  ['55', '近ツー', '近ツー', 'キンツー', 'NOUN', '名詞-固有名詞-一般', '', 'Show'],
#  ['56', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', 'Show'],
#  ['57', 'knt', 'KNT', 'KNT', 'NOUN', '名詞-固有名詞-一般', '', 'GOE_Other']]
# [['0', '@', '＠', 'アット', 'SYM', '補助記号-一般', '', ''],
#  ['1', 'tabi', 'tabi', 'tabi', 'PROPN', '名詞-普通名詞-一般', '', ''],
#  ['2', '317', '317', 'サンイチナナ', 'NUM', '名詞-数詞', '', '']]
# [['0', 'より', 'より', 'ヨリ', 'ADP', '副詞', '', '']]
# [['0', '【', '【', 'キゴウ', 'PUNCT', '補助記号-括弧開', '', ''],
#  ['1', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['2', '地域', '地域', 'チイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['3', 'おこし', 'おこし', 'オコシ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['4', '協力隊', '協力隊', 'キョウリョクタイ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['5', '募集', '募集', 'ボシュウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['6', '】', '】', 'キゴウ', 'PUNCT', '補助記号-括弧閉', '', ''],
#  ['7', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['8', '岩手県', '岩手県', 'イワテケン', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['9', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['10', '盛岡市', '盛岡市', 'モリオカシ', 'PROPN', '名詞-固有名詞-地名-一般', '', 'Province'],
#  ['11', '①', '1', 'イチ', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['12', '市', '市', 'シ', 'NOUN', '名詞-普通名詞-一般', '', 'Facility_Other'],
#  ['13', '総合', '総合', 'ソウゴウ', 'NOUN', '名詞-普通名詞-サ変可能', '', 'Facility_Other'],
#  ['14', '交流', '交流', 'コウリュウ', 'NOUN', '名詞-普通名詞-サ変可能', '', 'Facility_Other'],
#  ['15', 'ターミナル', 'ターミナル', 'ターミナル', 'NOUN', '名詞-普通名詞-一般', '', 'Facility_Other'],
#  ['16', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['17', '利用', '利用', 'リヨウ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['18', '促進', '促進', 'ソクシン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['19', 'と', 'と', 'ト', 'ADP', '助詞-格助詞', '', ''],
#  ['20', '地域', '地域', 'チイキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['21', '活性化', '活性化', 'カッセイカ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['22', '②', '2', 'ニ', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['23', '大学', '大学', 'ダイガク', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['24', '連携', '連携', 'レンケイ', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['25', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['26', 'よる', 'よる', 'ヨル', 'VERB', '動詞-一般', '五段-ラ行,連体形-一般', ''],
#  ['27', 'アグリ', 'アグリ', 'アグリ', 'NOUN', '名詞-普通名詞-一般', '', 'Plan'],
#  ['28', 'イノベーション', 'イノベーション', 'イノベーション', 'NOUN', '名詞-普通名詞-一般', '', 'Plan'],
#  ['29', '事業', '事業', 'ジギョウ', 'NOUN', '名詞-普通名詞-一般', '', 'Plan'],
#  ['30', '推進', '推進', 'スイシン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['31', '③', '3', 'サン', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['32', '芸術', '芸術', 'ゲイジュツ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['33', '文化', '文化', 'ブンカ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['34', 'まちづくり', 'まちづくり', 'マチヅクリ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['35', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['36', '推進', '推進', 'スイシン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['37', '④', '4', 'ヨン', 'NUM', '名詞-数詞', '', 'Ordinal_Number'],
#  ['38', '玉', '玉', 'タマ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'Class'],
#  ['39', '山', '山', 'ヤマ', 'NOUN', '名詞-普通名詞-一般', '', 'Class'],
#  ['40', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['41', '産品', '産品', 'サンヒン', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['42', 'を', 'を', 'ヲ', 'ADP', '助詞-格助詞', '', ''],
#  ['43', '道', '道', 'ミチ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['44', 'の', 'の', 'ノ', 'ADP', '助詞-格助詞', '', ''],
#  ['45', '駅', '駅', 'エキ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['46', 'から', 'から', 'カラ', 'ADP', '助詞-格助詞', '', ''],
#  ['47', '発信', '発信', 'ハッシン', 'NOUN', '名詞-普通名詞-サ変可能', '', ''],
#  ['48', '人数', '人数', 'ニンズウ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['49', ':', '：', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['50', '各', '各', 'カク', 'NOUN', '接頭辞', '', ''],
#  ['51', '１', '1', 'イチ', 'NUM', '名詞-数詞', '', 'N_Person'],
#  ['52', '名', '名', 'メイ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'N_Person'],
#  ['53', '期日', '期日', 'キジツ', 'NOUN', '名詞-普通名詞-一般', '', ''],
#  ['54', ':', '：', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['55', 'R', 'r', 'R', 'NOUN', '名詞-普通名詞-一般', '', 'Name_Other'],
#  ['56', '3', '3', 'サン', 'NUM', '名詞-数詞', '', 'Name_Other'],
#  ['57', '/', '/', 'キゴウ', 'SYM', '補助記号-一般', '', 'Name_Other'],
#  ['58', '10', '10', 'イチレイ', 'NUM', '名詞-数詞', '', 'Name_Other'],
#  ['59', '/', '/', 'キゴウ', 'SYM', '補助記号-一般', '', 'Name_Other'],
#  ['60', '29', '29', 'ニキュウ', 'NUM', '名詞-数詞', '', 'Name_Other'],
#  ['61', '詳細', '詳細', 'ショウサイ', 'NOUN', '名詞-普通名詞-形状詞可能', '', ''],
#  ['62', 'は', 'は', 'ハ', 'ADP', '助詞-係助詞', '', ''],
#  ['63', 'コチラ', 'コチラ', 'コチラ', 'PRON', '代名詞', '', ''],
#  ['64', '↓', '↓', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['65', 'http://', 'http:／／', 'エイチティーティーピー', 'X', '記号-一般', '', 'URL'],
#  ['66', 'city', 'CITY', 'シティー', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['67', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['68', 'morioka', 'morioka', 'morioka', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['69', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['70', 'iwate', 'iwate', 'iwate', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['71', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['72', 'jp', 'JP', 'ジェーピー', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['73', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['74', 'shisei', 'shisei', 'shisei', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['75', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['76',
#   'machizukuri',
#   'machizukuri',
#   'machizukuri',
#   'X',
#   '名詞-普通名詞-一般',
#   '',
#   'URL'],
#  ['77', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['78', '1020669', '1020669', 'イチレイニレイロクロクキュウ', 'X', '名詞-数詞', '', 'URL'],
#  ['79', '/', '/', 'キゴウ', 'X', '補助記号-一般', '', 'URL'],
#  ['80', 'index', 'INDEX', 'インデックス', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['81', '.', '.', '．', 'X', '補助記号-句点', '', 'URL'],
#  ['82', 'html', 'HTML', 'エイチティーエムエル', 'X', '名詞-普通名詞-一般', '', 'URL'],
#  ['83', '…', '.', 'ドット', 'X', '補助記号-句点', '', 'URL'],
#  ['84', '#', '#', 'キゴウ', 'SYM', '補助記号-一般', '', ''],
#  ['85', 'イーハトー', 'イーハトー', 'イーハトー', 'NOUN', '名詞-普通名詞-一般', '', 'GOE_Other'],
#  ['86', '部', '部', 'ブ', 'NOUN', '名詞-普通名詞-助数詞可能', '', 'GOE_Other'],
#  ['87', 'に', 'に', 'ニ', 'ADP', '助詞-格助詞', '', ''],
#  ['88', '入ろう', '入る', 'ハイロウ', 'VERB', '動詞-一般', '五段-ラ行,意志推量形', ''],
#  ['89', '！', '!', 'キゴウ', 'PUNCT', '補助記号-句点', '', '']]
